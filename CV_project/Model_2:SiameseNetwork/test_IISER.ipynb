# %%
# Cell to import libraries

import numpy as np
import random
from PIL import Image
from PIL.ImageOps import invert
import numpy as np
from torch import Tensor
from torch.utils.data import Dataset
import pickle
import torch
from torch.utils.data import DataLoader

# %%
# Import model functions and load the pre-trained model

from Model import SiameseConvNet, distance_metric
from torch import load

device = torch.device('cpu')
model = SiameseConvNet()
model.load_state_dict(load(open('Models/model_large_epoch_20', 'rb'), map_location=device))
# Out:
# <All keys matched successfully>

# %%
# Create path for both genuine images

base_path_genuine = 'Datasets/IISER_Genuine/Genuine/%d-G-%d.jpg'

# %%
# Create test dataset. Here, signatures of other users are considered forgeries 

test = []
n_samples_of_each_class = 1000

for _ in range(n_samples_of_each_class):
    anchor_person = random.randint(1, 34)
    anchor_sign = random.randint(1, 3)
    pos_sign = random.randint(1, 3)
    while (anchor_sign == pos_sign):
        pos_sign = random.randint(1, 3)
    neg_person = random.randint(1, 34)
    while (anchor_person == neg_person):
        neg_person = random.randint(1, 34)
    neg_sign = random.randint(1, 3)
    
    positive = [base_path_genuine % (anchor_person, anchor_sign), base_path_genuine % (anchor_person, pos_sign), 1]
    negative = [base_path_genuine % (anchor_person, anchor_sign), base_path_genuine % (neg_person, neg_sign), 0]
    test.append(positive)
    test.append(negative)

# %%
# Preprocessing and Dataloaders
# Preprocessing involves resizing and inverting the image before binarizing with a threshold intensity of 50

def invert_image(path):
	image_file = Image.open(path) # open colour image
	image_file = image_file.convert('L').resize([220, 155])
	image_file = invert(image_file)
	image_array = np.array(image_file)
	for i in range(image_array.shape[0]):
		for j in range(image_array.shape[1]):
			if image_array[i][j]<=50:
				image_array[i][j]=0
			else:
				image_array[i][j]=255
	return image_array

def convert_to_image_tensor(image_array):
	image_array = image_array/255.0
	return Tensor(image_array).view(1, 220, 155)


with open('test_index_IISER.pkl', 'wb') as test_index_file:
	pickle.dump(test, test_index_file)


class TestDataset(Dataset):

	def __init__(self):
		with open('test_index_IISER.pkl', 'rb') as test_index_file:
			self.pairs = pickle.load(test_index_file)

	def __getitem__(self, index):
		item = self.pairs[index]
		X = convert_to_image_tensor(invert_image(item[0]))
		Y = convert_to_image_tensor(invert_image(item[1]))
		return [X, Y, item[2]]

	def __len__(self):
		return len(self.pairs)

# %%
# Compute accuracy as average of True Positive and True Negative rates

def compute_accuracy_roc(predictions, labels):
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)
    step = 0.001
    max_acc = 0

    d_optimal = 0
    for d in np.arange(dmin, dmax + step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d

        tpr = float(np.sum(labels[idx1] == 1)) / nsame
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff

        acc = 0.5 * (tpr + tnr)

        if acc > max_acc:
            max_acc = acc
            d_optimal = d

    return max_acc, d_optimal

# %%
# Compute the accuracy on the test data set

batch_avg_acc = 0
batch_avg_d = 0
n_batch = 0


def test():
    model.eval()
    global batch_avg_acc, batch_avg_d, n_batch

    test_dataset = TestDataset()
    loader = DataLoader(test_dataset, batch_size=10, shuffle=True)

    for batch_index, data in enumerate(loader):
        A = data[0]
        B = data[1]
        labels = data[2].long()

        f_a, f_b = model.forward(A, B)
        dist = distance_metric(f_a, f_b)

        acc, d = compute_accuracy_roc(dist.detach().numpy(), labels.detach().numpy())
        print('Max accuracy for batch {} = {} at d = {}'.format(batch_index, acc, d))
        batch_avg_acc += acc
        batch_avg_d += d
        n_batch += 1


print('IISER:')
test()
print('Avg acc across all batches={} at d={}'.format(batch_avg_acc / n_batch, batch_avg_d / n_batch))
# Out:
# IISER:
# Max accuracy for batch 0 = 0.625 at d = 0.9270113137066365
# Max accuracy for batch 1 = 0.625 at d = 0.08601131370663644
# Max accuracy for batch 2 = 0.9 at d = 0.09901131370663643
# Max accuracy for batch 3 = 0.6666666666666666 at d = 0.40501131370663646
# Max accuracy for batch 4 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 5 = 0.7857142857142857 at d = 0.09901131370663643
# Max accuracy for batch 6 = 0.6 at d = 0.27501131370663645
# Max accuracy for batch 7 = 0.7142857142857143 at d = 0.17701131370663642
# Max accuracy for batch 8 = 0.5 at d = 0.8060113137066365
# Max accuracy for batch 9 = 0.75 at d = 1.1313706636428833e-05
# Max accuracy for batch 10 = 0.625 at d = 1.1313706636428833e-05
# Max accuracy for batch 11 = 0.5 at d = 0.40201131370663645
# Max accuracy for batch 12 = 0.6875 at d = 0.33701131370663645
# Max accuracy for batch 13 = 0.5 at d = 0.10501131370663642
# Max accuracy for batch 14 = 0.6875 at d = 0.23001131370663644
# Max accuracy for batch 15 = 0.7 at d = 0.09901131370663643
# Max accuracy for batch 16 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 17 = 0.6666666666666666 at d = 0.23001131370663644
# Max accuracy for batch 18 = 0.6 at d = 0.11701131370663644
# Max accuracy for batch 19 = 0.7142857142857143 at d = 0.02701131370663643
# Max accuracy for batch 20 = 0.8125 at d = 0.3040113137066364
# Max accuracy for batch 21 = 0.5 at d = 0.006011313706636429
# Max accuracy for batch 22 = 0.7142857142857143 at d = 0.5360113137066365
# Max accuracy for batch 23 = 0.7 at d = 0.22201131370663643
# Max accuracy for batch 24 = 0.8 at d = 0.40201131370663645
# Max accuracy for batch 25 = 0.75 at d = 0.40201131370663645
# Max accuracy for batch 26 = 0.6666666666666666 at d = 0.3520113137066364
# Max accuracy for batch 27 = 0.7083333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 28 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 29 = 0.6428571428571428 at d = 0.40201131370663645
# Max accuracy for batch 30 = 0.75 at d = 0.22801131370663644
# Max accuracy for batch 31 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 32 = 0.6875 at d = 0.3080113137066364
# Max accuracy for batch 33 = 0.9285714285714286 at d = 0.3520113137066364
# Max accuracy for batch 34 = 0.6 at d = 0.32701131370663644
# Max accuracy for batch 35 = 0.9166666666666667 at d = 1.1313706636428833e-05
# Max accuracy for batch 36 = 0.75 at d = 1.1313706636428833e-05
# Max accuracy for batch 37 = 0.6 at d = 0.006011313706636429
# Max accuracy for batch 38 = 0.8571428571428572 at d = 1.1313706636428833e-05
# Max accuracy for batch 39 = 0.5 at d = 0.8060113137066365
# Max accuracy for batch 40 = 0.5476190476190476 at d = 0.3520113137066364
# Max accuracy for batch 41 = 0.7916666666666667 at d = 0.13501131370663644
# Max accuracy for batch 42 = 0.9285714285714286 at d = 1.1313706636428833e-05
# Max accuracy for batch 43 = 0.75 at d = 0.40201131370663645
# Max accuracy for batch 44 = 0.6000000000000001 at d = 1.1313706636428833e-05
# Max accuracy for batch 45 = 1.0 at d = 0.47801131370663646
# Max accuracy for batch 46 = 0.6875 at d = 1.1313706636428833e-05
# Max accuracy for batch 47 = 0.5 at d = 0.40501131370663646
# Max accuracy for batch 48 = 0.5833333333333334 at d = 0.9270113137066365
# Max accuracy for batch 49 = 0.8333333333333333 at d = 0.2970113137066364
# Max accuracy for batch 50 = 1.0 at d = 0.3520113137066364
# Max accuracy for batch 51 = 0.6 at d = 0.40201131370663645
# Max accuracy for batch 52 = 0.875 at d = 0.17701131370663642
# Max accuracy for batch 53 = 0.9285714285714286 at d = 0.32701131370663644
# Max accuracy for batch 54 = 1.0 at d = 0.09901131370663643
# Max accuracy for batch 55 = 0.6666666666666666 at d = 0.3040113137066364
# Max accuracy for batch 56 = 0.6000000000000001 at d = 1.1313706636428833e-05
# Max accuracy for batch 57 = 0.5714285714285714 at d = 0.23001131370663644
# Max accuracy for batch 58 = 0.7142857142857143 at d = 1.1313706636428833e-05
# Max accuracy for batch 59 = 0.6666666666666667 at d = 0.08601131370663644
# Max accuracy for batch 60 = 0.8571428571428572 at d = 0.09801131370663643
# Max accuracy for batch 61 = 0.6666666666666666 at d = 0.33701131370663645
# Max accuracy for batch 62 = 0.8571428571428572 at d = 1.1313706636428833e-05
# Max accuracy for batch 63 = 0.7 at d = 0.22201131370663643
# Max accuracy for batch 64 = 0.7 at d = 0.5360113137066365
# Max accuracy for batch 65 = 0.5416666666666666 at d = 0.10201131370663644
# Max accuracy for batch 66 = 0.7 at d = 0.11701131370663644
# Max accuracy for batch 67 = 0.7857142857142857 at d = 1.1313706636428833e-05
# Max accuracy for batch 68 = 0.75 at d = 0.33701131370663645
# Max accuracy for batch 69 = 0.5 at d = 0.32701131370663644
# Max accuracy for batch 70 = 0.7083333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 71 = 0.6666666666666667 at d = 0.08601131370663644
# Max accuracy for batch 72 = 0.6666666666666667 at d = 0.40501131370663646
# Max accuracy for batch 73 = 0.5833333333333333 at d = 0.006011313706636429
# Max accuracy for batch 74 = 0.75 at d = 0.2970113137066364
# Max accuracy for batch 75 = 0.6666666666666666 at d = 0.13501131370663644
# Max accuracy for batch 76 = 0.7619047619047619 at d = 0.18001131370663642
# Max accuracy for batch 77 = 0.9166666666666667 at d = 0.006011313706636429
# Max accuracy for batch 78 = 0.75 at d = 0.07701131370663643
# Max accuracy for batch 79 = 0.5833333333333334 at d = 0.10501131370663642
# Max accuracy for batch 80 = 0.6904761904761905 at d = 1.1313706636428833e-05
# Max accuracy for batch 81 = 0.6428571428571428 at d = 0.17701131370663642
# Max accuracy for batch 82 = 0.8 at d = 0.02701131370663643
# Max accuracy for batch 83 = 0.8333333333333333 at d = 0.18001131370663642
# Max accuracy for batch 84 = 0.6904761904761905 at d = 1.1313706636428833e-05
# Max accuracy for batch 85 = 0.7916666666666667 at d = 1.1313706636428833e-05
# Max accuracy for batch 86 = 0.75 at d = 0.22801131370663644
# Max accuracy for batch 87 = 0.8571428571428572 at d = 1.1313706636428833e-05
# Max accuracy for batch 88 = 0.625 at d = 0.11701131370663644
# Max accuracy for batch 89 = 0.875 at d = 0.18001131370663642
# Max accuracy for batch 90 = 0.75 at d = 0.3080113137066364
# Max accuracy for batch 91 = 1.0 at d = 1.1313706636428833e-05
# Max accuracy for batch 92 = 0.8 at d = 0.3040113137066364
# Max accuracy for batch 93 = 0.6428571428571428 at d = 0.23901131370663645
# Max accuracy for batch 94 = 0.8 at d = 1.1313706636428833e-05
# Max accuracy for batch 95 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 96 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 97 = 0.625 at d = 1.1313706636428833e-05
# Max accuracy for batch 98 = 0.5833333333333334 at d = 0.40201131370663645
# Max accuracy for batch 99 = 0.9166666666666667 at d = 1.1313706636428833e-05
# Max accuracy for batch 100 = 0.5 at d = 0.8980113137066364
# Max accuracy for batch 101 = 0.625 at d = 0.3040113137066364
# Max accuracy for batch 102 = 0.75 at d = 0.3080113137066364
# Max accuracy for batch 103 = 0.8 at d = 0.22801131370663644
# Max accuracy for batch 104 = 0.6666666666666666 at d = 0.22801131370663644
# Max accuracy for batch 105 = 0.7857142857142857 at d = 0.10201131370663644
# Max accuracy for batch 106 = 0.9285714285714286 at d = 1.1313706636428833e-05
# Max accuracy for batch 107 = 0.6666666666666667 at d = 0.3040113137066364
# Max accuracy for batch 108 = 0.7083333333333333 at d = 0.13501131370663644
# Max accuracy for batch 109 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 110 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 111 = 1.0 at d = 0.10201131370663644
# Max accuracy for batch 112 = 0.6904761904761905 at d = 1.1313706636428833e-05
# Max accuracy for batch 113 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 114 = 0.8571428571428572 at d = 1.1313706636428833e-05
# Max accuracy for batch 115 = 0.6 at d = 0.11701131370663644
# Max accuracy for batch 116 = 0.8333333333333333 at d = 1.1313706636428833e-05
# Max accuracy for batch 117 = 0.8125 at d = 1.1313706636428833e-05
# Max accuracy for batch 118 = 0.7 at d = 0.22801131370663644
# Max accuracy for batch 119 = 0.7857142857142857 at d = 0.10501131370663642
# Max accuracy for batch 120 = 0.6 at d = 0.10501131370663642
# Max accuracy for batch 121 = 0.9375 at d = 0.3040113137066364
# Max accuracy for batch 122 = 0.6000000000000001 at d = 0.13501131370663644
# Max accuracy for batch 123 = 0.7857142857142857 at d = 1.1313706636428833e-05
# Max accuracy for batch 124 = 0.6190476190476191 at d = 0.33701131370663645
# Max accuracy for batch 125 = 0.6666666666666666 at d = 0.08901131370663642
# Max accuracy for batch 126 = 0.5 at d = 0.07701131370663643
# Max accuracy for batch 127 = 0.5 at d = 0.8060113137066365
# Max accuracy for batch 128 = 0.9166666666666667 at d = 0.08901131370663642
# Max accuracy for batch 129 = 0.75 at d = 0.01701131370663643
# Max accuracy for batch 130 = 0.6666666666666666 at d = 0.33701131370663645
# Max accuracy for batch 131 = 0.7083333333333333 at d = 0.08901131370663642
# Max accuracy for batch 132 = 0.8571428571428572 at d = 1.1313706636428833e-05
# Max accuracy for batch 133 = 0.7916666666666667 at d = 0.13501131370663644
# Max accuracy for batch 134 = 0.6 at d = 0.8980113137066364
# Max accuracy for batch 135 = 0.9166666666666667 at d = 0.006011313706636429
# Max accuracy for batch 136 = 0.8 at d = 0.3520113137066364
# Max accuracy for batch 137 = 0.7142857142857143 at d = 0.17701131370663642
# Max accuracy for batch 138 = 0.6666666666666666 at d = 0.27501131370663645
# Max accuracy for batch 139 = 0.75 at d = 0.23901131370663645
# Max accuracy for batch 140 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 141 = 0.8333333333333333 at d = 0.09401131370663643
# Max accuracy for batch 142 = 0.8 at d = 0.18001131370663642
# Max accuracy for batch 143 = 0.75 at d = 0.27501131370663645
# Max accuracy for batch 144 = 0.6428571428571428 at d = 0.27501131370663645
# Max accuracy for batch 145 = 0.6 at d = 0.08601131370663644
# Max accuracy for batch 146 = 1.0 at d = 0.18001131370663642
# Max accuracy for batch 147 = 0.7 at d = 0.13501131370663644
# Max accuracy for batch 148 = 0.6666666666666666 at d = 1.1313706636428833e-05
# Max accuracy for batch 149 = 0.8571428571428572 at d = 0.2970113137066364
# Max accuracy for batch 150 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 151 = 1.0 at d = 0.02701131370663643
# Max accuracy for batch 152 = 0.625 at d = 0.3520113137066364
# Max accuracy for batch 153 = 0.5 at d = 0.40501131370663646
# Max accuracy for batch 154 = 0.7916666666666667 at d = 0.02701131370663643
# Max accuracy for batch 155 = 0.75 at d = 0.3265540627799928
# Max accuracy for batch 156 = 0.6666666666666666 at d = 0.44501131370663644
# Max accuracy for batch 157 = 0.6 at d = 0.006011313706636429
# Max accuracy for batch 158 = 0.75 at d = 0.17701131370663642
# Max accuracy for batch 159 = 0.5238095238095238 at d = 0.23001131370663644
# Max accuracy for batch 160 = 0.7142857142857143 at d = 0.40501131370663646
# Max accuracy for batch 161 = 0.8333333333333333 at d = 0.07701131370663643
# Max accuracy for batch 162 = 0.8571428571428572 at d = 0.006011313706636429
# Max accuracy for batch 163 = 0.6666666666666666 at d = 0.01701131370663643
# Max accuracy for batch 164 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 165 = 0.5 at d = 0.47801131370663646
# Max accuracy for batch 166 = 0.6 at d = 0.44501131370663644
# Max accuracy for batch 167 = 0.5833333333333334 at d = 0.13501131370663644
# Max accuracy for batch 168 = 0.7857142857142857 at d = 0.02701131370663643
# Max accuracy for batch 169 = 0.625 at d = 1.1313706636428833e-05
# Max accuracy for batch 170 = 0.8333333333333333 at d = 0.3040113137066364
# Max accuracy for batch 171 = 0.5 at d = 0.23001131370663644
# Max accuracy for batch 172 = 0.9 at d = 0.2970113137066364
# Max accuracy for batch 173 = 0.6666666666666667 at d = 0.006011313706636429
# Max accuracy for batch 174 = 0.5625 at d = 0.3080113137066364
# Max accuracy for batch 175 = 0.6875 at d = 0.3520113137066364
# Max accuracy for batch 176 = 0.875 at d = 1.1313706636428833e-05
# Max accuracy for batch 177 = 0.7142857142857143 at d = 1.1313706636428833e-05
# Max accuracy for batch 178 = 0.6428571428571428 at d = 0.40201131370663645
# Max accuracy for batch 179 = 0.7619047619047619 at d = 0.10501131370663642
# Max accuracy for batch 180 = 0.6000000000000001 at d = 0.10201131370663644
# Max accuracy for batch 181 = 0.5476190476190476 at d = 0.10501131370663642
# Max accuracy for batch 182 = 0.6904761904761905 at d = 0.09801131370663643
# Max accuracy for batch 183 = 0.75 at d = 0.3080113137066364
# Max accuracy for batch 184 = 1.0 at d = 0.09401131370663643
# Max accuracy for batch 185 = 0.8 at d = 0.7990113137066365
# Max accuracy for batch 186 = 0.5 at d = 0.3520113137066364
# Max accuracy for batch 187 = 0.75 at d = 0.006011313706636429
# Max accuracy for batch 188 = 0.7 at d = 0.40201131370663645
# Max accuracy for batch 189 = 0.8333333333333333 at d = 0.11701131370663644
# Max accuracy for batch 190 = 0.6190476190476191 at d = 0.11701131370663644
# Max accuracy for batch 191 = 0.7916666666666667 at d = 0.01701131370663643
# Max accuracy for batch 192 = 0.625 at d = 0.15001131370663642
# Max accuracy for batch 193 = 0.75 at d = 0.32701131370663644
# Max accuracy for batch 194 = 0.8571428571428572 at d = 0.02701131370663643
# Max accuracy for batch 195 = 0.7083333333333333 at d = 0.02701131370663643
# Max accuracy for batch 196 = 0.7 at d = 0.09801131370663643
# Max accuracy for batch 197 = 0.6666666666666666 at d = 0.07001131370663644
# Max accuracy for batch 198 = 0.7 at d = 1.1313706636428833e-05
# Max accuracy for batch 199 = 0.7 at d = 0.3080113137066364
# Avg acc across all batches=0.7207113095238092 at d=0.18872902745200318
