# %%
# Cell to import libraries

import numpy as np
import random
from PIL import Image
from PIL.ImageOps import invert
import numpy as np
from torch import Tensor
from torch.utils.data import Dataset
import pickle
import torch
from torch.utils.data import DataLoader

# %%
# Import model functions and load the pre-trained model

from Model import SiameseConvNet, distance_metric
from torch import load

device = torch.device('cpu')
model = SiameseConvNet()
model.load_state_dict(load(open('Models/model_large_epoch_20', 'rb'), map_location=device))
# Out:
# <All keys matched successfully>

# %%
# Create path for both genuine and forgery images

base_path_genuine = 'Datasets/BHSig260-Bengali/Genuine/B-S-%d-G-%s.tif'
base_path_forgery = 'Datasets/BHSig260-Bengali/Forgery/B-S-%d-F-%s.tif'

# %%
# Create test dataset. The rationale for number of samples is in the appendix of the report

test = []
n_samples_of_each_class = 3682

for _ in range(n_samples_of_each_class):
    anchor_person = random.randint(1, 100)
    anchor_sign = random.randint(1, 24)
    pos_sign = random.randint(1, 24)
    while (anchor_sign == pos_sign):
        pos_sign = random.randint(1, 24)
    neg_sign = random.randint(1, 30)
    if anchor_sign < 10:
        anchor_sign = "0" + str(anchor_sign)
    if pos_sign < 10:
        pos_sign = "0" + str(pos_sign)
    if neg_sign < 10:
        neg_sign = "0" + str(neg_sign)
    positive = [base_path_genuine % (anchor_person, anchor_sign), base_path_genuine % (anchor_person, pos_sign), 1]
    negative = [base_path_genuine % (anchor_person, anchor_sign), base_path_forgery % (anchor_person, neg_sign), 0]
    test.append(positive)
    test.append(negative)

# %%
# Preprocessing and Dataloaders
# Preprocessing involves resizing and inverting the image before binarizing with a threshold intensity of 50

def invert_image(path):
	image_file = Image.open(path) # open colour image
	image_file = image_file.convert('L').resize([220, 155])
	image_file = invert(image_file)
	image_array = np.array(image_file)
	for i in range(image_array.shape[0]):
		for j in range(image_array.shape[1]):
			if image_array[i][j]<=50:
				image_array[i][j]=0
			else:
				image_array[i][j]=255
	return image_array

def convert_to_image_tensor(image_array):
	image_array = image_array/255.0
	return Tensor(image_array).view(1, 220, 155)


with open('test_index_BHSigB.pkl', 'wb') as test_index_file:
	pickle.dump(test, test_index_file)


class TestDataset(Dataset):

	def __init__(self):
		with open('test_index_BHSigB.pkl', 'rb') as test_index_file:
			self.pairs = pickle.load(test_index_file)

	def __getitem__(self, index):
		item = self.pairs[index]
		X = convert_to_image_tensor(invert_image(item[0]))
		Y = convert_to_image_tensor(invert_image(item[1]))
		return [X, Y, item[2]]

	def __len__(self):
		return len(self.pairs)

# %%
# Compute accuracy as average of True Positive and True Negative rates

def compute_accuracy_roc(predictions, labels):
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)
    step = 0.001
    max_acc = 0

    d_optimal = 0
    for d in np.arange(dmin, dmax + step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d

        tpr = float(np.sum(labels[idx1] == 1)) / nsame
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff

        acc = 0.5 * (tpr + tnr)

        if acc > max_acc:
            max_acc = acc
            d_optimal = d

    return max_acc, d_optimal

# %%
# Compute the accuracy on the test data set

batch_avg_acc = 0
batch_avg_d = 0
n_batch = 0


def test():
    model.eval()
    global batch_avg_acc, batch_avg_d, n_batch

    test_dataset = TestDataset()
    loader = DataLoader(test_dataset, batch_size=10, shuffle=True)

    for batch_index, data in enumerate(loader):
        A = data[0]
        B = data[1]
        labels = data[2].long()

        f_a, f_b = model.forward(A, B)
        dist = distance_metric(f_a, f_b)

        acc, d = compute_accuracy_roc(dist.detach().numpy(), labels.detach().numpy())
        print('Max accuracy for batch {} = {} at d = {}'.format(batch_index, acc, d))
        batch_avg_acc += acc
        batch_avg_d += d
        n_batch += 1


print('BHSigB:')
test()
print('Avg acc across all batches={} at d={}'.format(batch_avg_acc / n_batch, batch_avg_d / n_batch))
# Out:
# BHSigB:
# Max accuracy for batch 0 = 0.625 at d = 0.058779806345701235
# Max accuracy for batch 1 = 0.7619047619047619 at d = 0.13451007428765305
# Max accuracy for batch 2 = 0.7 at d = 0.07343119269609455
# Max accuracy for batch 3 = 0.625 at d = 0.01796450838446617
# Max accuracy for batch 4 = 0.8333333333333333 at d = 0.05984264904260639
# Max accuracy for batch 5 = 0.6000000000000001 at d = 0.0511943150162697
# Max accuracy for batch 6 = 0.7142857142857143 at d = 0.0487057643979788
# Max accuracy for batch 7 = 0.875 at d = 0.11201131370663643
# Max accuracy for batch 8 = 0.5952380952380952 at d = 0.2193247511833908
# Max accuracy for batch 9 = 0.875 at d = 0.10728269095718868
# Max accuracy for batch 10 = 0.8571428571428572 at d = 0.09730710491538053
# Max accuracy for batch 11 = 0.9166666666666667 at d = 0.15428865750879062
# Max accuracy for batch 12 = 0.75 at d = 0.11694645085930833
# Max accuracy for batch 13 = 0.6111111111111112 at d = 0.2834645841121676
# Max accuracy for batch 14 = 0.6666666666666666 at d = 0.04208850669860842
# Max accuracy for batch 15 = 0.9 at d = 0.16023015558719644
# Max accuracy for batch 16 = 0.7 at d = 0.1079177364110947
# Max accuracy for batch 17 = 0.625 at d = 0.14806015825271612
# Max accuracy for batch 18 = 0.8333333333333333 at d = 0.08857931177318101
# Max accuracy for batch 19 = 0.6666666666666666 at d = 0.17472254019975675
# Max accuracy for batch 20 = 0.6666666666666667 at d = 0.13708436745405206
# Max accuracy for batch 21 = 0.75 at d = 0.15740225760638726
# Max accuracy for batch 22 = 0.8333333333333333 at d = 0.16953646856546412
# Max accuracy for batch 23 = 0.9285714285714286 at d = 0.08956143377721315
# Max accuracy for batch 24 = 0.8125 at d = 0.06719553893804553
# Max accuracy for batch 25 = 0.7 at d = 0.07696852216124539
# Max accuracy for batch 26 = 0.6000000000000001 at d = 0.057109083443880104
# Max accuracy for batch 27 = 0.7083333333333333 at d = 0.04990247616171839
# Max accuracy for batch 28 = 0.9 at d = 0.09661154413223272
# Max accuracy for batch 29 = 0.6666666666666667 at d = 0.09460304056108004
# Max accuracy for batch 30 = 0.9444444444444444 at d = 0.1465243550837041
# Max accuracy for batch 31 = 0.8333333333333333 at d = 0.11969523167610174
# Max accuracy for batch 32 = 0.8 at d = 0.11316744053363803
# Max accuracy for batch 33 = 0.75 at d = 0.24105737289786355
# Max accuracy for batch 34 = 0.6428571428571428 at d = 0.30999782472848914
# Max accuracy for batch 35 = 0.8333333333333333 at d = 0.11614074409008035
# Max accuracy for batch 36 = 0.6666666666666666 at d = 0.02595091052353382
# Max accuracy for batch 37 = 0.8 at d = 0.11994682955741887
# Max accuracy for batch 38 = 0.75 at d = 0.12551598456501967
# Max accuracy for batch 39 = 0.9166666666666667 at d = 0.09619448052346713
# Max accuracy for batch 40 = 0.8 at d = 0.07658333414793017
# Max accuracy for batch 41 = 0.5833333333333334 at d = 0.20048882928490652
# Max accuracy for batch 42 = 0.7857142857142857 at d = 0.11263643705844884
# Max accuracy for batch 43 = 0.625 at d = 0.09124686777591706
# Max accuracy for batch 44 = 0.8571428571428572 at d = 0.1429978215098382
# Max accuracy for batch 45 = 0.75 at d = 0.0541372662484646
# Max accuracy for batch 46 = 0.9 at d = 0.07700072719156748
# Max accuracy for batch 47 = 0.6666666666666666 at d = 0.040878364443779014
# Max accuracy for batch 48 = 0.8 at d = 0.13669552350044256
# Max accuracy for batch 49 = 0.9 at d = 0.12128963291645056
# Max accuracy for batch 50 = 0.6428571428571428 at d = 0.19526565277576458
# Max accuracy for batch 51 = 0.75 at d = 0.21398718863725674
# Max accuracy for batch 52 = 0.8 at d = 0.1127154366075993
# Max accuracy for batch 53 = 0.9 at d = 0.07361515043675904
# Max accuracy for batch 54 = 0.7142857142857143 at d = 0.1029995683431626
# Max accuracy for batch 55 = 0.6666666666666667 at d = 0.10515503802895554
# Max accuracy for batch 56 = 0.625 at d = 0.27554272174835226
# Max accuracy for batch 57 = 0.625 at d = 0.14482857976853858
# Max accuracy for batch 58 = 0.7 at d = 0.1235899167358876
# Max accuracy for batch 59 = 0.6875 at d = 0.06101131370663643
# Max accuracy for batch 60 = 0.7916666666666667 at d = 0.06943849547207359
# Max accuracy for batch 61 = 0.7916666666666667 at d = 0.12376392713189133
# Max accuracy for batch 62 = 0.8333333333333333 at d = 0.25801131370663644
# Max accuracy for batch 63 = 0.625 at d = 0.10310693031549456
# Max accuracy for batch 64 = 0.875 at d = 0.133690000474453
# Max accuracy for batch 65 = 0.6666666666666667 at d = 0.10895278328657154
# Max accuracy for batch 66 = 0.75 at d = 0.0801630065888167
# Max accuracy for batch 67 = 0.7916666666666667 at d = 0.10819279882311827
# Max accuracy for batch 68 = 1.0 at d = 0.16629636073112497
# Max accuracy for batch 69 = 0.7 at d = 0.13114368695020684
# Max accuracy for batch 70 = 0.9 at d = 0.03301131370663643
# Max accuracy for batch 71 = 0.7142857142857143 at d = 0.15996394634246835
# Max accuracy for batch 72 = 0.9375 at d = 0.08144396622478967
# Max accuracy for batch 73 = 0.5 at d = 0.2954812296330931
# Max accuracy for batch 74 = 0.75 at d = 0.04338369651138785
# Max accuracy for batch 75 = 0.625 at d = 0.0835601300299168
# Max accuracy for batch 76 = 0.6000000000000001 at d = 0.17250719785690316
# Max accuracy for batch 77 = 0.875 at d = 0.05627631375193598
# Max accuracy for batch 78 = 1.0 at d = 0.14332884664833556
# Max accuracy for batch 79 = 0.75 at d = 0.15937089854478848
# Max accuracy for batch 80 = 0.6666666666666667 at d = 0.1186258262991906
# Max accuracy for batch 81 = 0.8333333333333333 at d = 0.05155716475844385
# Max accuracy for batch 82 = 0.7619047619047619 at d = 0.10958633169531828
# Max accuracy for batch 83 = 0.6 at d = 1.1313706636428833e-05
# Max accuracy for batch 84 = 0.75 at d = 0.11537385231256492
# Max accuracy for batch 85 = 0.875 at d = 0.10107309877872472
# Max accuracy for batch 86 = 0.7 at d = 0.13240026998519905
# Max accuracy for batch 87 = 0.6666666666666666 at d = 0.06470824307203293
# Max accuracy for batch 88 = 0.8 at d = 0.12899693959951408
# Max accuracy for batch 89 = 0.8 at d = 0.05192104712128642
# Max accuracy for batch 90 = 0.6666666666666667 at d = 0.07397740752995019
# Max accuracy for batch 91 = 0.75 at d = 0.050168964028358465
# Max accuracy for batch 92 = 0.9285714285714286 at d = 0.08001131370663643
# Max accuracy for batch 93 = 1.0 at d = 0.062407152310013814
# Max accuracy for batch 94 = 0.6428571428571428 at d = 0.22011032357811944
# Max accuracy for batch 95 = 0.8333333333333333 at d = 0.03576789358258248
# Max accuracy for batch 96 = 0.7916666666666667 at d = 0.13476926815509804
# Max accuracy for batch 97 = 0.7 at d = 0.0665838806629181
# Max accuracy for batch 98 = 0.9 at d = 0.09963198381662375
# Max accuracy for batch 99 = 0.75 at d = 0.06239225009083749
# Max accuracy for batch 100 = 0.75 at d = 0.042761562287807475
# Max accuracy for batch 101 = 0.75 at d = 0.07601674035191541
# Max accuracy for batch 102 = 0.9285714285714286 at d = 0.08602560664713388
# Max accuracy for batch 103 = 0.625 at d = 0.109793017923832
# Max accuracy for batch 104 = 0.7 at d = 0.10260039636492735
# Max accuracy for batch 105 = 0.75 at d = 0.2760969329476358
# Max accuracy for batch 106 = 0.6904761904761905 at d = 0.11292219921946534
# Max accuracy for batch 107 = 0.8 at d = 0.12295405060052877
# Max accuracy for batch 108 = 1.0 at d = 0.0696249652653933
# Max accuracy for batch 109 = 0.7 at d = 0.056243289440870314
# Max accuracy for batch 110 = 0.75 at d = 0.1436221230328084
# Max accuracy for batch 111 = 0.6666666666666667 at d = 0.15054578860104095
# Max accuracy for batch 112 = 0.5833333333333334 at d = 0.15742673164606102
# Max accuracy for batch 113 = 0.8333333333333333 at d = 0.08701131370663644
# Max accuracy for batch 114 = 0.7 at d = 0.05253752863407135
# Max accuracy for batch 115 = 0.6 at d = 0.048227954655885696
# Max accuracy for batch 116 = 0.8333333333333333 at d = 0.17426570230722438
# Max accuracy for batch 117 = 0.8 at d = 0.04402434350550177
# Max accuracy for batch 118 = 0.7 at d = 0.18435493457317365
# Max accuracy for batch 119 = 1.0 at d = 0.0358449051976204
# Max accuracy for batch 120 = 0.9 at d = 0.09164420029520992
# Max accuracy for batch 121 = 0.7857142857142857 at d = 0.15960109195113192
# Max accuracy for batch 122 = 0.7083333333333333 at d = 0.09521313151717192
# Max accuracy for batch 123 = 0.7857142857142857 at d = 0.12767562311887748
# Max accuracy for batch 124 = 0.6666666666666666 at d = 0.047276029914617546
# Max accuracy for batch 125 = 0.75 at d = 0.04901131370663643
# Max accuracy for batch 126 = 0.8 at d = 0.05097740752995017
# Max accuracy for batch 127 = 0.5833333333333333 at d = 0.08063323946297174
# Max accuracy for batch 128 = 0.7 at d = 0.06811136518418792
# Max accuracy for batch 129 = 0.8 at d = 0.176035890646279
# Max accuracy for batch 130 = 1.0 at d = 0.0380744125545025
# Max accuracy for batch 131 = 0.7857142857142857 at d = 0.04665052261948588
# Max accuracy for batch 132 = 0.9375 at d = 0.10722599861025817
# Max accuracy for batch 133 = 0.8571428571428572 at d = 0.10591787612438208
# Max accuracy for batch 134 = 0.7 at d = 0.12023757687211045
# Max accuracy for batch 135 = 0.75 at d = 0.045650008037686374
# Max accuracy for batch 136 = 0.7857142857142857 at d = 0.0892408448159695
# Max accuracy for batch 137 = 1.0 at d = 0.1154184147715569
# Max accuracy for batch 138 = 0.8333333333333333 at d = 0.027877888754010205
# Max accuracy for batch 139 = 0.7 at d = 0.0692580361068249
# Max accuracy for batch 140 = 0.75 at d = 0.03625143966078759
# Max accuracy for batch 141 = 0.875 at d = 0.07677330604195598
# Max accuracy for batch 142 = 0.75 at d = 0.18487700366973892
# Max accuracy for batch 143 = 0.5833333333333334 at d = 0.053987570106983185
# Max accuracy for batch 144 = 1.0 at d = 0.08333275610208513
# Max accuracy for batch 145 = 0.6428571428571428 at d = 0.04611807410418989
# Max accuracy for batch 146 = 0.9 at d = 0.15919311028718952
# Max accuracy for batch 147 = 0.7619047619047619 at d = 0.04519874235987664
# Max accuracy for batch 148 = 0.7 at d = 0.04535579167306425
# Max accuracy for batch 149 = 0.75 at d = 0.08697714582085614
# Max accuracy for batch 150 = 0.7142857142857143 at d = 0.19678166031837474
# Max accuracy for batch 151 = 0.75 at d = 0.09606695526838305
# Max accuracy for batch 152 = 0.8333333333333333 at d = 0.1227239598035813
# Max accuracy for batch 153 = 0.8571428571428572 at d = 0.15779059112072003
# Max accuracy for batch 154 = 0.8 at d = 0.1326434543132783
# Max accuracy for batch 155 = 0.9166666666666667 at d = 0.12429446670413025
# Max accuracy for batch 156 = 0.75 at d = 0.2261075222790243
# Max accuracy for batch 157 = 0.625 at d = 0.07380187961459161
# Max accuracy for batch 158 = 0.8333333333333333 at d = 0.07170416241884237
# Max accuracy for batch 159 = 1.0 at d = 0.08101131370663643
# Max accuracy for batch 160 = 0.7916666666666667 at d = 0.1301075664758683
# Max accuracy for batch 161 = 0.5 at d = 0.3069266505241396
# Max accuracy for batch 162 = 0.75 at d = 1.1313706636428833e-05
# Max accuracy for batch 163 = 0.9166666666666667 at d = 0.14078853940963754
# Max accuracy for batch 164 = 0.9375 at d = 0.15638794261217126
# Max accuracy for batch 165 = 0.75 at d = 0.10787432809174069
# Max accuracy for batch 166 = 0.8 at d = 0.07677739503979686
# Max accuracy for batch 167 = 0.75 at d = 0.055818375542759924
# Max accuracy for batch 168 = 0.9 at d = 0.08164747893810276
# Max accuracy for batch 169 = 0.75 at d = 0.057623403429985065
# Max accuracy for batch 170 = 0.6666666666666666 at d = 0.06765884234011177
# Max accuracy for batch 171 = 1.0 at d = 0.11872874045372017
# Max accuracy for batch 172 = 0.6000000000000001 at d = 0.16901131370663644
# Max accuracy for batch 173 = 0.8 at d = 0.09471320313215259
# Max accuracy for batch 174 = 0.9375 at d = 0.08302834570407869
# Max accuracy for batch 175 = 0.7083333333333333 at d = 0.09901131370663643
# Max accuracy for batch 176 = 0.6666666666666666 at d = 0.15701131370663643
# Max accuracy for batch 177 = 0.5 at d = 0.23520471230149287
# Max accuracy for batch 178 = 0.7916666666666667 at d = 0.11601131370663643
# Max accuracy for batch 179 = 0.75 at d = 0.07357346266508102
# Max accuracy for batch 180 = 0.6000000000000001 at d = 0.19201131370663643
# Max accuracy for batch 181 = 0.75 at d = 0.07901131370663643
# Max accuracy for batch 182 = 0.5625 at d = 0.06901279091835022
# Max accuracy for batch 183 = 0.6666666666666666 at d = 0.07992574465274815
# Max accuracy for batch 184 = 0.8 at d = 0.06591200029850008
# Max accuracy for batch 185 = 0.9 at d = 0.09118331599235541
# Max accuracy for batch 186 = 0.75 at d = 0.20378856974840176
# Max accuracy for batch 187 = 0.9166666666666667 at d = 0.08470203247666364
# Max accuracy for batch 188 = 0.6666666666666667 at d = 0.11102988573908812
# Max accuracy for batch 189 = 0.8 at d = 0.149696385473013
# Max accuracy for batch 190 = 0.7916666666666667 at d = 0.07013784432411196
# Max accuracy for batch 191 = 0.6000000000000001 at d = 0.16117198288440715
# Max accuracy for batch 192 = 0.7916666666666667 at d = 0.1637940765619279
# Max accuracy for batch 193 = 0.8 at d = 0.09807692015171054
# Max accuracy for batch 194 = 0.9 at d = 0.18889484083652508
# Max accuracy for batch 195 = 0.8333333333333333 at d = 0.062119923919439324
# Max accuracy for batch 196 = 0.6666666666666666 at d = 0.11803409713506707
# Max accuracy for batch 197 = 0.9 at d = 0.058206029534339905
# Max accuracy for batch 198 = 0.7916666666666667 at d = 0.11706067061424263
# Max accuracy for batch 199 = 0.875 at d = 0.08756348848342899
# Max accuracy for batch 200 = 0.8 at d = 0.12727250003814705
# Max accuracy for batch 201 = 0.8125 at d = 0.09801131370663643
# Max accuracy for batch 202 = 0.5714285714285714 at d = 0.2870769201517107
# Max accuracy for batch 203 = 0.6000000000000001 at d = 0.09300992223620419
# Max accuracy for batch 204 = 0.7 at d = 0.2922176071703436
# Max accuracy for batch 205 = 0.8333333333333333 at d = 0.18081968715786945
# Max accuracy for batch 206 = 0.8571428571428572 at d = 0.11545598571002491
# Max accuracy for batch 207 = 0.75 at d = 0.1596832674741746
# Max accuracy for batch 208 = 0.7916666666666667 at d = 0.088673717096448
# Max accuracy for batch 209 = 0.6666666666666666 at d = 0.032828640192747116
# Max accuracy for batch 210 = 0.75 at d = 0.05319942370057107
# Max accuracy for batch 211 = 0.6000000000000001 at d = 0.14501131370663642
# Max accuracy for batch 212 = 0.625 at d = 0.044657789170742035
# Max accuracy for batch 213 = 0.7 at d = 0.18305370190739645
# Max accuracy for batch 214 = 0.8 at d = 0.12479150703549391
# Max accuracy for batch 215 = 0.6666666666666667 at d = 0.07067350113391879
# Max accuracy for batch 216 = 0.8571428571428572 at d = 0.13269230327010162
# Max accuracy for batch 217 = 0.9285714285714286 at d = 0.08050362247228626
# Max accuracy for batch 218 = 0.8333333333333333 at d = 0.053336544573307054
# Max accuracy for batch 219 = 0.875 at d = 0.05788670185208322
# Max accuracy for batch 220 = 0.8571428571428572 at d = 0.11199468305706983
# Max accuracy for batch 221 = 0.8333333333333333 at d = 0.1815974888801576
# Max accuracy for batch 222 = 0.75 at d = 0.058474618673324597
# Max accuracy for batch 223 = 0.75 at d = 0.21227695542573943
# Max accuracy for batch 224 = 0.6666666666666666 at d = 0.06101131370663643
# Max accuracy for batch 225 = 0.7083333333333333 at d = 0.11512960374355319
# Max accuracy for batch 226 = 0.6666666666666667 at d = 0.08518645350635057
# Max accuracy for batch 227 = 0.7 at d = 0.1041391205191613
# Max accuracy for batch 228 = 0.5 at d = 0.37741987827420265
# Max accuracy for batch 229 = 0.6666666666666666 at d = 0.05291746124625207
# Max accuracy for batch 230 = 0.625 at d = 0.1063980251252652
# Max accuracy for batch 231 = 0.8571428571428572 at d = 0.09301131370663643
# Max accuracy for batch 232 = 0.7 at d = 0.16179991534352312
# Max accuracy for batch 233 = 0.8571428571428572 at d = 0.08101131370663643
# Max accuracy for batch 234 = 0.75 at d = 0.057366573154926326
# Max accuracy for batch 235 = 0.7 at d = 0.0499123125076294
# Max accuracy for batch 236 = 0.8333333333333333 at d = 0.05101131370663643
# Max accuracy for batch 237 = 0.5 at d = 0.28156074596941494
# Max accuracy for batch 238 = 0.7916666666666667 at d = 0.10997458441555508
# Max accuracy for batch 239 = 0.8 at d = 0.036561433777213104
# Max accuracy for batch 240 = 0.7142857142857143 at d = 0.2576545488834383
# Max accuracy for batch 241 = 0.7857142857142857 at d = 0.13356355351209648
# Max accuracy for batch 242 = 0.9444444444444444 at d = 0.11011652958393103
# Max accuracy for batch 243 = 0.6000000000000001 at d = 0.06712001699209214
# Max accuracy for batch 244 = 0.9285714285714286 at d = 0.09940090499818333
# Max accuracy for batch 245 = 0.8 at d = 0.10253141471743588
# Max accuracy for batch 246 = 0.8 at d = 0.06454962092638017
# Max accuracy for batch 247 = 0.8333333333333333 at d = 0.1790050273239614
# Max accuracy for batch 248 = 0.9285714285714286 at d = 0.09995815801620489
# Max accuracy for batch 249 = 0.8 at d = 0.1326356318593026
# Max accuracy for batch 250 = 0.9 at d = 0.1315222122073174
# Max accuracy for batch 251 = 0.5 at d = 0.07900973603129391
# Max accuracy for batch 252 = 0.8333333333333333 at d = 0.1391744169294835
# Max accuracy for batch 253 = 0.75 at d = 0.04181142935156823
# Max accuracy for batch 254 = 0.6428571428571428 at d = 0.15683168041706097
# Max accuracy for batch 255 = 0.875 at d = 0.03801131370663643
# Max accuracy for batch 256 = 0.6666666666666666 at d = 0.060975796047598126
# Max accuracy for batch 257 = 0.8 at d = 0.07932378113269811
# Max accuracy for batch 258 = 0.5833333333333334 at d = 0.2776883798241617
# Max accuracy for batch 259 = 0.8333333333333333 at d = 0.1048696664869786
# Max accuracy for batch 260 = 0.6904761904761905 at d = 0.10785681955516346
# Max accuracy for batch 261 = 0.875 at d = 0.16829737910628328
# Max accuracy for batch 262 = 0.6666666666666666 at d = 0.06151983514428139
# Max accuracy for batch 263 = 0.75 at d = 0.06036285683512688
# Max accuracy for batch 264 = 0.7916666666666667 at d = 0.12278113117814071
# Max accuracy for batch 265 = 0.8 at d = 0.10252532261610037
# Max accuracy for batch 266 = 0.8333333333333333 at d = 0.15348056621849548
# Max accuracy for batch 267 = 1.0 at d = 0.1837415793836118
# Max accuracy for batch 268 = 1.0 at d = 0.0639388664364815
# Max accuracy for batch 269 = 0.8333333333333333 at d = 0.19302524036169066
# Max accuracy for batch 270 = 0.875 at d = 0.1617012612372638
# Max accuracy for batch 271 = 0.7916666666666667 at d = 0.1322640290558339
# Max accuracy for batch 272 = 0.5714285714285714 at d = 1.1313706636428833e-05
# Max accuracy for batch 273 = 0.6666666666666666 at d = 0.019942641258239746
# Max accuracy for batch 274 = 0.5714285714285714 at d = 0.06424075365066528
# Max accuracy for batch 275 = 0.7619047619047619 at d = 0.13501131370663644
# Max accuracy for batch 276 = 0.7 at d = 0.06929520803689959
# Max accuracy for batch 277 = 0.7916666666666667 at d = 0.09268031907081609
# Max accuracy for batch 278 = 0.7142857142857143 at d = 0.11737784230709081
# Max accuracy for batch 279 = 0.625 at d = 0.22166957134008425
# Max accuracy for batch 280 = 0.75 at d = 0.09074831360578539
# Max accuracy for batch 281 = 0.75 at d = 0.0740105192065239
# Max accuracy for batch 282 = 0.7 at d = 0.06295987226068978
# Max accuracy for batch 283 = 0.6666666666666666 at d = 0.20856221973896039
# Max accuracy for batch 284 = 0.7619047619047619 at d = 0.0466319838166237
# Max accuracy for batch 285 = 0.5833333333333333 at d = 0.13604960209131245
# Max accuracy for batch 286 = 0.7 at d = 0.0496408130824566
# Max accuracy for batch 287 = 0.7857142857142857 at d = 0.07541981735825543
# Max accuracy for batch 288 = 0.75 at d = 0.11597291862964632
# Max accuracy for batch 289 = 0.75 at d = 0.20201131370663644
# Max accuracy for batch 290 = 0.5952380952380952 at d = 0.07161328849196436
# Max accuracy for batch 291 = 0.8333333333333333 at d = 0.08501131370663643
# Max accuracy for batch 292 = 0.7857142857142857 at d = 0.08270202639698987
# Max accuracy for batch 293 = 0.9 at d = 0.12991705207526694
# Max accuracy for batch 294 = 0.75 at d = 0.20065700867772118
# Max accuracy for batch 295 = 0.9 at d = 0.07393886643648151
# Max accuracy for batch 296 = 0.7 at d = 0.19301131370663643
# Max accuracy for batch 297 = 0.8333333333333333 at d = 0.1586479401588441
# Max accuracy for batch 298 = 0.7857142857142857 at d = 0.060548494204878844
# Max accuracy for batch 299 = 0.6428571428571428 at d = 0.05249110406637192
# Max accuracy for batch 300 = 0.8 at d = 0.08965912133455278
# Max accuracy for batch 301 = 0.9166666666666667 at d = 0.12807670533657078
# Max accuracy for batch 302 = 0.5 at d = 0.08545452517271046
# Max accuracy for batch 303 = 0.7 at d = 0.05215056213736535
# Max accuracy for batch 304 = 0.7 at d = 0.28094649571180363
# Max accuracy for batch 305 = 0.8333333333333333 at d = 0.13155037754774102
# Max accuracy for batch 306 = 0.5714285714285714 at d = 1.1313706636428833e-05
# Max accuracy for batch 307 = 0.5833333333333334 at d = 0.017514029517769814
# Max accuracy for batch 308 = 0.9375 at d = 0.055508246272802375
# Max accuracy for batch 309 = 0.7857142857142857 at d = 0.13706965649127967
# Max accuracy for batch 310 = 0.875 at d = 0.0689623626172543
# Max accuracy for batch 311 = 0.875 at d = 0.09901131370663643
# Max accuracy for batch 312 = 0.9 at d = 0.08277741055190568
# Max accuracy for batch 313 = 0.8 at d = 0.10860516172647483
# Max accuracy for batch 314 = 0.875 at d = 0.15453695949912083
# Max accuracy for batch 315 = 0.75 at d = 0.09260405910015113
# Max accuracy for batch 316 = 0.7916666666666667 at d = 0.1380066849142314
# Max accuracy for batch 317 = 0.9 at d = 0.08573615109920507
# Max accuracy for batch 318 = 0.8 at d = 0.11912062224745756
# Max accuracy for batch 319 = 0.6666666666666666 at d = 0.0465695783495903
# Max accuracy for batch 320 = 0.7 at d = 0.029482447490096098
# Max accuracy for batch 321 = 0.75 at d = 0.18856974627077594
# Max accuracy for batch 322 = 0.75 at d = 0.04609085187315942
# Max accuracy for batch 323 = 0.5 at d = 0.10834930855035785
# Max accuracy for batch 324 = 0.75 at d = 0.10943898296356203
# Max accuracy for batch 325 = 0.8 at d = 0.13479284754395493
# Max accuracy for batch 326 = 0.9 at d = 0.0577512533068657
# Max accuracy for batch 327 = 0.7 at d = 0.06304731160402299
# Max accuracy for batch 328 = 0.7 at d = 0.04405933624505998
# Max accuracy for batch 329 = 0.6428571428571428 at d = 0.06917241874337199
# Max accuracy for batch 330 = 0.6 at d = 0.1574436198771001
# Max accuracy for batch 331 = 0.7619047619047619 at d = 0.09215506201982504
# Max accuracy for batch 332 = 0.6666666666666667 at d = 0.15750337649881851
# Max accuracy for batch 333 = 0.6666666666666667 at d = 0.1303694625496865
# Max accuracy for batch 334 = 0.9166666666666667 at d = 0.05001131370663643
# Max accuracy for batch 335 = 0.75 at d = 0.07265415295958522
# Max accuracy for batch 336 = 0.9285714285714286 at d = 0.12501131370663643
# Max accuracy for batch 337 = 0.9 at d = 0.08832324823737148
# Max accuracy for batch 338 = 1.0 at d = 0.08215125729143624
# Max accuracy for batch 339 = 0.8 at d = 0.07336538845300677
# Max accuracy for batch 340 = 0.7222222222222222 at d = 0.1694371514618398
# Max accuracy for batch 341 = 0.75 at d = 0.06697916930913927
# Max accuracy for batch 342 = 0.8 at d = 0.09783004178106791
# Max accuracy for batch 343 = 0.9 at d = 0.09264223368465907
# Max accuracy for batch 344 = 0.5 at d = 0.0936166268587113
# Max accuracy for batch 345 = 0.6428571428571428 at d = 0.15937104985117923
# Max accuracy for batch 346 = 0.7142857142857143 at d = 0.06292596444487575
# Max accuracy for batch 347 = 0.6428571428571428 at d = 0.0952560177147389
# Max accuracy for batch 348 = 0.6666666666666666 at d = 0.14518692469596872
# Max accuracy for batch 349 = 0.7 at d = 0.05320443822443488
# Max accuracy for batch 350 = 0.7 at d = 0.05660878369212152
# Max accuracy for batch 351 = 0.8 at d = 0.08009717428684238
# Max accuracy for batch 352 = 0.7 at d = 0.08173615109920507
# Max accuracy for batch 353 = 0.75 at d = 0.042220367997884756
# Max accuracy for batch 354 = 0.75 at d = 0.08058523947000507
# Max accuracy for batch 355 = 0.8333333333333333 at d = 0.15397916930913935
# Max accuracy for batch 356 = 0.6666666666666666 at d = 0.03511986508965492
# Max accuracy for batch 357 = 0.6875 at d = 0.09765175174176699
# Max accuracy for batch 358 = 0.5 at d = 0.4847114821076397
# Max accuracy for batch 359 = 0.6190476190476191 at d = 0.0817009537816048
# Max accuracy for batch 360 = 0.8 at d = 0.11963813233375553
# Max accuracy for batch 361 = 0.7 at d = 0.19827656017243878
# Max accuracy for batch 362 = 0.7083333333333333 at d = 0.10027087470889096
# Max accuracy for batch 363 = 0.875 at d = 0.05861236506700518
# Max accuracy for batch 364 = 0.8 at d = 0.05104609480500222
# Max accuracy for batch 365 = 0.6428571428571428 at d = 0.06351858821511269
# Max accuracy for batch 366 = 0.8571428571428572 at d = 0.11992291456460957
# Max accuracy for batch 367 = 0.875 at d = 0.1310175672471524
# Max accuracy for batch 368 = 0.8333333333333333 at d = 0.034145705461502085
# Max accuracy for batch 369 = 0.75 at d = 0.18346900975704206
# Max accuracy for batch 370 = 0.6666666666666666 at d = 0.06372353699803357
# Max accuracy for batch 371 = 0.8125 at d = 0.11246289145946509
# Max accuracy for batch 372 = 1.0 at d = 0.09479352724552159
# Max accuracy for batch 373 = 0.8 at d = 0.1342649863511325
# Max accuracy for batch 374 = 0.7 at d = 0.177355313897133
# Max accuracy for batch 375 = 0.6666666666666666 at d = 0.04023855508863927
# Max accuracy for batch 376 = 1.0 at d = 0.03775249016284943
# Max accuracy for batch 377 = 0.7916666666666667 at d = 0.11747094860672957
# Max accuracy for batch 378 = 0.9375 at d = 0.046970612376928345
# Max accuracy for batch 379 = 1.0 at d = 0.07578090974688534
# Max accuracy for batch 380 = 1.0 at d = 0.05725785516202453
# Max accuracy for batch 381 = 0.875 at d = 0.10225906774401672
# Max accuracy for batch 382 = 0.6000000000000001 at d = 0.11301131370663643
# Max accuracy for batch 383 = 0.625 at d = 0.2420669083893301
# Max accuracy for batch 384 = 0.9 at d = 0.17505375596880923
# Max accuracy for batch 385 = 0.5833333333333334 at d = 0.039806339889764786
# Max accuracy for batch 386 = 0.9166666666666667 at d = 0.09570107366144665
# Max accuracy for batch 387 = 0.7916666666666667 at d = 0.06848258060216905
# Max accuracy for batch 388 = 0.6111111111111112 at d = 0.1554407753944398
# Max accuracy for batch 389 = 0.7619047619047619 at d = 0.13531234103441248
# Max accuracy for batch 390 = 0.6 at d = 0.05405157059431076
# Max accuracy for batch 391 = 0.6666666666666666 at d = 0.06790896353125575
# Max accuracy for batch 392 = 0.7916666666666667 at d = 0.06415074467658999
# Max accuracy for batch 393 = 0.75 at d = 0.048761921554803855
# Max accuracy for batch 394 = 0.6000000000000001 at d = 0.09426132553815847
# Max accuracy for batch 395 = 0.7083333333333333 at d = 0.08702031043171887
# Max accuracy for batch 396 = 0.5555555555555556 at d = 0.2457298477888109
# Max accuracy for batch 397 = 0.7142857142857143 at d = 0.20026405486464516
# Max accuracy for batch 398 = 0.7619047619047619 at d = 0.07102369260787966
# Max accuracy for batch 399 = 0.6904761904761905 at d = 0.08801131370663642
# Max accuracy for batch 400 = 0.9375 at d = 0.08241633760929112
# Max accuracy for batch 401 = 0.75 at d = 0.10765127658843998
# Max accuracy for batch 402 = 0.7916666666666667 at d = 0.14333183240890512
# Max accuracy for batch 403 = 0.7857142857142857 at d = 0.06983375200629238
# Max accuracy for batch 404 = 0.7 at d = 0.06026001954078675
# Max accuracy for batch 405 = 0.7 at d = 0.0860773997455836
# Max accuracy for batch 406 = 0.7 at d = 0.08732764780521396
# Max accuracy for batch 407 = 0.8 at d = 0.13775871939957152
# Max accuracy for batch 408 = 0.6666666666666666 at d = 0.04752195626497269
# Max accuracy for batch 409 = 0.8125 at d = 0.09839951172471051
# Max accuracy for batch 410 = 0.625 at d = 0.07915303856134415
# Max accuracy for batch 411 = 1.0 at d = 0.07097090780735016
# Max accuracy for batch 412 = 0.7083333333333333 at d = 0.09646520109474666
# Max accuracy for batch 413 = 0.9166666666666667 at d = 0.0758529098629952
# Max accuracy for batch 414 = 0.875 at d = 0.09009902636706835
# Max accuracy for batch 415 = 0.6666666666666666 at d = 0.05819036549329759
# Max accuracy for batch 416 = 0.75 at d = 0.03791582688689232
# Max accuracy for batch 417 = 0.8125 at d = 0.08814100369811062
# Max accuracy for batch 418 = 0.7 at d = 0.14967592629790316
# Max accuracy for batch 419 = 1.0 at d = 0.02949583487212659
# Max accuracy for batch 420 = 0.6666666666666667 at d = 0.05877067664265634
# Max accuracy for batch 421 = 0.8 at d = 0.05287452217936517
# Max accuracy for batch 422 = 0.75 at d = 0.1961250923275949
# Max accuracy for batch 423 = 1.0 at d = 0.07964141586422924
# Max accuracy for batch 424 = 0.875 at d = 0.2890113137066364
# Max accuracy for batch 425 = 0.75 at d = 0.21963566949963587
# Max accuracy for batch 426 = 0.7857142857142857 at d = 0.1147565017044545
# Max accuracy for batch 427 = 0.7142857142857143 at d = 0.06971854722499848
# Max accuracy for batch 428 = 0.8333333333333333 at d = 0.16907266856729997
# Max accuracy for batch 429 = 0.75 at d = 0.08657195344567303
# Max accuracy for batch 430 = 0.8333333333333333 at d = 0.042950910523533836
# Max accuracy for batch 431 = 0.8333333333333333 at d = 0.027213591590523722
# Max accuracy for batch 432 = 0.8 at d = 0.2011548897624017
# Max accuracy for batch 433 = 0.6666666666666667 at d = 0.13496914330869914
# Max accuracy for batch 434 = 0.7916666666666667 at d = 0.12334960871934897
# Max accuracy for batch 435 = 0.8125 at d = 0.13842998766899117
# Max accuracy for batch 436 = 0.8571428571428572 at d = 0.15651740166544925
# Max accuracy for batch 437 = 0.9166666666666667 at d = 0.10941831862926488
# Max accuracy for batch 438 = 0.7083333333333333 at d = 0.15099252963066112
# Max accuracy for batch 439 = 0.6875 at d = 0.08501812297105793
# Max accuracy for batch 440 = 0.8 at d = 0.06278251561522485
# Max accuracy for batch 441 = 0.9 at d = 0.03936762560904028
# Max accuracy for batch 442 = 0.5 at d = 0.22624738681316392
# Max accuracy for batch 443 = 0.8125 at d = 0.07247515605390076
# Max accuracy for batch 444 = 0.7 at d = 0.15119352345168602
# Max accuracy for batch 445 = 0.7916666666666667 at d = 0.07461674430966381
# Max accuracy for batch 446 = 0.7916666666666667 at d = 0.14410459676384935
# Max accuracy for batch 447 = 0.75 at d = 0.06725876033306122
# Max accuracy for batch 448 = 0.5416666666666667 at d = 0.20600566023588196
# Max accuracy for batch 449 = 0.8 at d = 0.10401131370663644
# Max accuracy for batch 450 = 0.6875 at d = 0.17600115773081793
# Max accuracy for batch 451 = 0.6666666666666666 at d = 0.09613423746824268
# Max accuracy for batch 452 = 0.5952380952380952 at d = 0.13201131370663644
# Max accuracy for batch 453 = 0.8333333333333333 at d = 0.05428885093331337
# Max accuracy for batch 454 = 0.7619047619047619 at d = 0.11381330712139615
# Max accuracy for batch 455 = 0.75 at d = 0.18657994180917747
# Max accuracy for batch 456 = 0.8125 at d = 0.15195070305466662
# Max accuracy for batch 457 = 0.5833333333333333 at d = 0.07097356669604782
# Max accuracy for batch 458 = 0.8571428571428572 at d = 0.13502599114179614
# Max accuracy for batch 459 = 0.5416666666666666 at d = 0.07944291469454767
# Max accuracy for batch 460 = 0.7 at d = 0.04882139077782632
# Max accuracy for batch 461 = 0.9 at d = 0.05948346602916721
# Max accuracy for batch 462 = 0.8333333333333333 at d = 0.1542611829340459
# Max accuracy for batch 463 = 0.8333333333333333 at d = 0.06954004962742333
# Max accuracy for batch 464 = 0.8571428571428572 at d = 0.06501131370663643
# Max accuracy for batch 465 = 0.6 at d = 0.05929938331246376
# Max accuracy for batch 466 = 1.0 at d = 0.07493702998757368
# Max accuracy for batch 467 = 0.9 at d = 0.11034684659540661
# Max accuracy for batch 468 = 0.7083333333333333 at d = 0.1305252351760865
# Max accuracy for batch 469 = 0.7857142857142857 at d = 0.07853501445055011
# Max accuracy for batch 470 = 0.9 at d = 0.217295486405492
# Max accuracy for batch 471 = 0.75 at d = 0.14597443775832664
# Max accuracy for batch 472 = 1.0 at d = 0.06540842744708064
# Max accuracy for batch 473 = 1.0 at d = 0.13201131370663644
# Max accuracy for batch 474 = 1.0 at d = 0.04845589876174927
# Max accuracy for batch 475 = 0.5625 at d = 0.11752837625145918
# Max accuracy for batch 476 = 0.625 at d = 0.07092932426929477
# Max accuracy for batch 477 = 0.875 at d = 0.12512235178053388
# Max accuracy for batch 478 = 0.875 at d = 0.11089658910036093
# Max accuracy for batch 479 = 0.8333333333333333 at d = 0.1351934849321843
# Max accuracy for batch 480 = 0.8333333333333333 at d = 0.09889058454334743
# Max accuracy for batch 481 = 0.7916666666666667 at d = 0.18156733331084263
# Max accuracy for batch 482 = 0.9166666666666667 at d = 0.07930008921027187
# Max accuracy for batch 483 = 1.0 at d = 0.08717084667086605
# Max accuracy for batch 484 = 0.9444444444444444 at d = 0.1210260000526906
# Max accuracy for batch 485 = 0.8571428571428572 at d = 0.07273297303915027
# Max accuracy for batch 486 = 0.8 at d = 0.07642300838232041
# Max accuracy for batch 487 = 0.9 at d = 0.10781642940640457
# Max accuracy for batch 488 = 0.8 at d = 0.08162067109346394
# Max accuracy for batch 489 = 0.7083333333333333 at d = 0.1322792857885361
# Max accuracy for batch 490 = 0.5 at d = 0.27303238536417507
# Max accuracy for batch 491 = 0.5714285714285714 at d = 0.0652954950928688
# Max accuracy for batch 492 = 0.75 at d = 0.14062109342217455
# Max accuracy for batch 493 = 0.5833333333333334 at d = 0.04840220883488655
# Max accuracy for batch 494 = 0.8 at d = 0.06823649680614474
# Max accuracy for batch 495 = 0.6428571428571428 at d = 0.0560998117476702
# Max accuracy for batch 496 = 0.75 at d = 0.06367721349000932
# Max accuracy for batch 497 = 0.6666666666666666 at d = 0.0732837689816952
# Max accuracy for batch 498 = 0.8 at d = 0.12064958000183112
# Max accuracy for batch 499 = 0.7 at d = 0.09661820691823964
# Max accuracy for batch 500 = 0.75 at d = 0.12644361987710007
# Max accuracy for batch 501 = 0.75 at d = 0.09035599365830427
# Max accuracy for batch 502 = 0.7619047619047619 at d = 0.1240921467989684
# Max accuracy for batch 503 = 1.0 at d = 0.0914583275318146
# Max accuracy for batch 504 = 1.0 at d = 0.044011313706636426
# Max accuracy for batch 505 = 0.875 at d = 0.06584736213088038
# Max accuracy for batch 506 = 0.7916666666666667 at d = 0.1144652255773545
# Max accuracy for batch 507 = 0.9 at d = 0.18231016808748257
# Max accuracy for batch 508 = 0.8 at d = 0.05595105180144311
# Max accuracy for batch 509 = 0.6666666666666666 at d = 0.09242899715900421
# Max accuracy for batch 510 = 0.75 at d = 0.05347605866193772
# Max accuracy for batch 511 = 0.8333333333333333 at d = 0.055567333310842515
# Max accuracy for batch 512 = 0.9166666666666667 at d = 0.11000298273563391
# Max accuracy for batch 513 = 0.875 at d = 0.1069934167861939
# Max accuracy for batch 514 = 0.8 at d = 0.1230141520798207
# Max accuracy for batch 515 = 0.7 at d = 0.07291899731755258
# Max accuracy for batch 516 = 0.7 at d = 0.08849650710821155
# Max accuracy for batch 517 = 0.75 at d = 0.18507441315054907
# Max accuracy for batch 518 = 0.6000000000000001 at d = 0.0688465943336487
# Max accuracy for batch 519 = 0.9 at d = 0.06296527162194254
# Max accuracy for batch 520 = 0.7 at d = 0.06096717157959941
# Max accuracy for batch 521 = 0.8 at d = 0.11354147788882263
# Max accuracy for batch 522 = 0.8 at d = 0.104659994006157
# Max accuracy for batch 523 = 0.5 at d = 0.20186671736836448
# Max accuracy for batch 524 = 1.0 at d = 0.06708278524875644
# Max accuracy for batch 525 = 0.8 at d = 0.05429927408695223
# Max accuracy for batch 526 = 0.9166666666666667 at d = 0.06576897084712985
# Max accuracy for batch 527 = 0.9375 at d = 0.10094865930080421
# Max accuracy for batch 528 = 0.9 at d = 0.11399820083379753
# Max accuracy for batch 529 = 0.7619047619047619 at d = 0.17668714003264918
# Max accuracy for batch 530 = 0.5833333333333334 at d = 0.060111016035079956
# Max accuracy for batch 531 = 0.9166666666666667 at d = 0.13047155275940903
# Max accuracy for batch 532 = 0.5952380952380952 at d = 0.10714712888002398
# Max accuracy for batch 533 = 0.9375 at d = 0.14273487666249285
# Max accuracy for batch 534 = 0.9166666666666667 at d = 0.07201131370663644
# Max accuracy for batch 535 = 0.8 at d = 0.07902801787853242
# Max accuracy for batch 536 = 0.8333333333333333 at d = 0.1004887337982655
# Max accuracy for batch 537 = 0.7142857142857143 at d = 0.10541554433107381
# Max accuracy for batch 538 = 0.7 at d = 0.05353516407310965
# Max accuracy for batch 539 = 0.8125 at d = 0.09901131370663643
# Max accuracy for batch 540 = 0.8333333333333333 at d = 0.08392873051762584
# Max accuracy for batch 541 = 0.7916666666666667 at d = 0.15466120767593394
# Max accuracy for batch 542 = 0.9166666666666667 at d = 0.10632892322540288
# Max accuracy for batch 543 = 0.7857142857142857 at d = 0.18077754342556007
# Max accuracy for batch 544 = 0.875 at d = 0.13750722341239463
# Max accuracy for batch 545 = 0.9375 at d = 0.07380764111876492
# Max accuracy for batch 546 = 0.7916666666666667 at d = 0.08129444637894634
# Max accuracy for batch 547 = 0.875 at d = 0.09269312694668774
# Max accuracy for batch 548 = 0.9285714285714286 at d = 0.12594880872964864
# Max accuracy for batch 549 = 0.8 at d = 0.052288657508790526
# Max accuracy for batch 550 = 0.7857142857142857 at d = 0.08276789358258252
# Max accuracy for batch 551 = 0.5952380952380952 at d = 0.09562163040041927
# Max accuracy for batch 552 = 0.625 at d = 0.04610225558280945
# Max accuracy for batch 553 = 0.6666666666666666 at d = 0.14373653611540804
# Max accuracy for batch 554 = 0.75 at d = 0.06143040046095849
# Max accuracy for batch 555 = 1.0 at d = 0.13361469238996515
# Max accuracy for batch 556 = 1.0 at d = 0.06923255324363708
# Max accuracy for batch 557 = 0.9375 at d = 0.16684023132920278
# Max accuracy for batch 558 = 0.8571428571428572 at d = 0.05601131370663643
# Max accuracy for batch 559 = 0.6666666666666666 at d = 0.16120586687326444
# Max accuracy for batch 560 = 0.75 at d = 0.12357257243990905
# Max accuracy for batch 561 = 0.8 at d = 0.14056038409471516
# Max accuracy for batch 562 = 0.6666666666666666 at d = 0.01935330033302307
# Max accuracy for batch 563 = 0.8333333333333333 at d = 0.18855736580491078
# Max accuracy for batch 564 = 0.7 at d = 0.047148014366626745
# Max accuracy for batch 565 = 0.7083333333333333 at d = 0.10041604726016529
# Max accuracy for batch 566 = 0.7083333333333333 at d = 0.07905486749112611
# Max accuracy for batch 567 = 1.0 at d = 0.1765027110874654
# Max accuracy for batch 568 = 1.0 at d = 0.08241830620169643
# Max accuracy for batch 569 = 1.0 at d = 0.11470328170061117
# Max accuracy for batch 570 = 0.75 at d = 0.18692843675613413
# Max accuracy for batch 571 = 0.8333333333333333 at d = 0.06669351093471054
# Max accuracy for batch 572 = 0.7 at d = 0.1112501821517945
# Max accuracy for batch 573 = 0.625 at d = 0.07604470451176171
# Max accuracy for batch 574 = 0.9285714285714286 at d = 0.10250268128514295
# Max accuracy for batch 575 = 0.8 at d = 0.11308357259631163
# Max accuracy for batch 576 = 0.7 at d = 0.050315121471881885
# Max accuracy for batch 577 = 0.7857142857142857 at d = 0.061767184734344505
# Max accuracy for batch 578 = 0.7142857142857143 at d = 0.09840653356909757
# Max accuracy for batch 579 = 0.6666666666666666 at d = 0.03566165268421173
# Max accuracy for batch 580 = 0.7 at d = 0.07655294579267502
# Max accuracy for batch 581 = 0.75 at d = 0.047728096634149564
# Max accuracy for batch 582 = 0.7916666666666667 at d = 0.1356784574389458
# Max accuracy for batch 583 = 0.8 at d = 0.05915107107162476
# Max accuracy for batch 584 = 0.8333333333333333 at d = 0.06277508969604972
# Max accuracy for batch 585 = 0.875 at d = 0.16701131370663644
# Max accuracy for batch 586 = 0.5625 at d = 0.11930169251561173
# Max accuracy for batch 587 = 0.9285714285714286 at d = 0.06792753213644032
# Max accuracy for batch 588 = 1.0 at d = 0.09437407419085508
# Max accuracy for batch 589 = 0.8571428571428572 at d = 0.09301131370663643
# Max accuracy for batch 590 = 0.875 at d = 0.10076467515528209
# Max accuracy for batch 591 = 0.8333333333333333 at d = 0.14476229977607735
# Max accuracy for batch 592 = 0.7 at d = 0.1726244805902244
# Max accuracy for batch 593 = 0.7619047619047619 at d = 0.08901131370663642
# Max accuracy for batch 594 = 0.9 at d = 0.11263986751437194
# Max accuracy for batch 595 = 0.625 at d = 0.057298555970191956
# Max accuracy for batch 596 = 0.9166666666666667 at d = 0.10454223877191549
# Max accuracy for batch 597 = 0.9 at d = 0.09225436368584639
# Max accuracy for batch 598 = 0.8333333333333333 at d = 0.09758516766130931
# Max accuracy for batch 599 = 0.6 at d = 0.2143707647919656
# Max accuracy for batch 600 = 0.8 at d = 0.14412475579977047
# Max accuracy for batch 601 = 0.6875 at d = 0.0787847254276276
# Max accuracy for batch 602 = 0.9375 at d = 0.11923812749981888
# Max accuracy for batch 603 = 0.7 at d = 0.10135493457317357
# Max accuracy for batch 604 = 0.5833333333333334 at d = 1.1313706636428833e-05
# Max accuracy for batch 605 = 0.75 at d = 1.1313706636428833e-05
# Max accuracy for batch 606 = 0.75 at d = 0.18656072904169574
# Max accuracy for batch 607 = 0.8333333333333333 at d = 0.06372785219550137
# Max accuracy for batch 608 = 0.5833333333333334 at d = 0.06783822178840637
# Max accuracy for batch 609 = 0.75 at d = 0.05301131370663643
# Max accuracy for batch 610 = 0.7916666666666667 at d = 0.14801131370663642
# Max accuracy for batch 611 = 0.5 at d = 0.34109295353293445
# Max accuracy for batch 612 = 0.6000000000000001 at d = 0.05461893138289453
# Max accuracy for batch 613 = 0.75 at d = 0.05991150528192524
# Max accuracy for batch 614 = 0.7916666666666667 at d = 0.15475871939957153
# Max accuracy for batch 615 = 0.75 at d = 0.05370916640758516
# Max accuracy for batch 616 = 0.75 at d = 0.12867674526572237
# Max accuracy for batch 617 = 0.7857142857142857 at d = 0.09444377289712436
# Max accuracy for batch 618 = 0.6666666666666667 at d = 0.08065103116631511
# Max accuracy for batch 619 = 0.75 at d = 0.02530689351260662
# Max accuracy for batch 620 = 0.7 at d = 0.20832834190130245
# Max accuracy for batch 621 = 0.7083333333333333 at d = 0.10501131370663642
# Max accuracy for batch 622 = 0.6666666666666667 at d = 0.08244058272242549
# Max accuracy for batch 623 = 0.8333333333333333 at d = 0.02301131370663643
# Max accuracy for batch 624 = 0.875 at d = 0.06755353417992593
# Max accuracy for batch 625 = 0.625 at d = 0.07923765903711322
# Max accuracy for batch 626 = 0.875 at d = 0.07292645025253297
# Max accuracy for batch 627 = 0.9285714285714286 at d = 0.05834344813227654
# Max accuracy for batch 628 = 0.8333333333333333 at d = 0.06683682015538217
# Max accuracy for batch 629 = 0.8333333333333333 at d = 0.11001131370663643
# Max accuracy for batch 630 = 0.9285714285714286 at d = 0.09091868418455129
# Max accuracy for batch 631 = 1.0 at d = 0.3020113137066364
# Max accuracy for batch 632 = 0.6875 at d = 0.15384088987112055
# Max accuracy for batch 633 = 0.7916666666666667 at d = 0.08601131370663644
# Max accuracy for batch 634 = 0.7 at d = 0.08892990574240689
# Max accuracy for batch 635 = 0.875 at d = 0.029750493526458754
# Max accuracy for batch 636 = 0.75 at d = 0.14871161621809015
# Max accuracy for batch 637 = 0.875 at d = 0.1380800088196994
# Max accuracy for batch 638 = 0.8 at d = 0.054647478938102734
# Max accuracy for batch 639 = 0.875 at d = 0.04268335464596751
# Max accuracy for batch 640 = 1.0 at d = 0.15115893724560747
# Max accuracy for batch 641 = 1.0 at d = 0.17610429069399847
# Max accuracy for batch 642 = 0.7142857142857143 at d = 0.10945814335346227
# Max accuracy for batch 643 = 0.9 at d = 0.07168510398268702
# Max accuracy for batch 644 = 0.625 at d = 0.04594257101416588
# Max accuracy for batch 645 = 0.9166666666666667 at d = 0.12773659320920716
# Max accuracy for batch 646 = 0.5 at d = 0.06548254939168696
# Max accuracy for batch 647 = 0.75 at d = 0.05201131370663643
# Max accuracy for batch 648 = 0.8 at d = 0.055292973309755356
# Max accuracy for batch 649 = 0.9285714285714286 at d = 0.1273247511833907
# Max accuracy for batch 650 = 0.9 at d = 0.20335885253548636
# Max accuracy for batch 651 = 0.5 at d = 0.2541504516303541
# Max accuracy for batch 652 = 0.5 at d = 0.16948424646258364
# Max accuracy for batch 653 = 0.875 at d = 0.1814126217365266
# Max accuracy for batch 654 = 0.875 at d = 0.1825664930492641
# Max accuracy for batch 655 = 0.6666666666666666 at d = 0.049351911783218405
# Max accuracy for batch 656 = 0.8333333333333333 at d = 0.196236284017563
# Max accuracy for batch 657 = 0.7 at d = 0.08068858543038371
# Max accuracy for batch 658 = 0.6666666666666667 at d = 0.13953246323764334
# Max accuracy for batch 659 = 0.9 at d = 0.07780843762308365
# Max accuracy for batch 660 = 0.6428571428571428 at d = 0.22273583504557626
# Max accuracy for batch 661 = 0.75 at d = 0.09264334683120257
# Max accuracy for batch 662 = 0.75 at d = 0.06436144584417347
# Max accuracy for batch 663 = 0.7 at d = 0.1316873714327813
# Max accuracy for batch 664 = 0.7857142857142857 at d = 0.07120878404378894
# Max accuracy for batch 665 = 0.6666666666666666 at d = 0.05228678816556931
# Max accuracy for batch 666 = 0.75 at d = 0.06765743970870974
# Max accuracy for batch 667 = 0.6666666666666666 at d = 0.07999513739347464
# Max accuracy for batch 668 = 0.75 at d = 0.07660577589273454
# Max accuracy for batch 669 = 0.7857142857142857 at d = 0.05940496550500396
# Max accuracy for batch 670 = 0.7619047619047619 at d = 0.19507060205936444
# Max accuracy for batch 671 = 0.7777777777777778 at d = 0.16966777479648598
# Max accuracy for batch 672 = 0.9 at d = 0.05553036403656009
# Max accuracy for batch 673 = 0.7 at d = 0.0853320937752724
# Max accuracy for batch 674 = 0.9285714285714286 at d = 0.0878275026082993
# Max accuracy for batch 675 = 0.5 at d = 0.21746110522747053
# Max accuracy for batch 676 = 0.875 at d = 0.18143680593371403
# Max accuracy for batch 677 = 0.7083333333333333 at d = 0.13389823901653297
# Max accuracy for batch 678 = 0.625 at d = 0.029699714854359627
# Max accuracy for batch 679 = 0.8 at d = 0.06863130006194118
# Max accuracy for batch 680 = 0.625 at d = 0.19552642294764533
# Max accuracy for batch 681 = 0.8888888888888888 at d = 0.09909970122575762
# Max accuracy for batch 682 = 0.7 at d = 0.14457204383611688
# Max accuracy for batch 683 = 0.625 at d = 0.1713699316084386
# Max accuracy for batch 684 = 0.75 at d = 0.07885921901464465
# Max accuracy for batch 685 = 0.7083333333333333 at d = 0.09707104745507245
# Max accuracy for batch 686 = 0.7777777777777778 at d = 0.06271197719872001
# Max accuracy for batch 687 = 0.7857142857142857 at d = 0.05601131370663643
# Max accuracy for batch 688 = 0.6000000000000001 at d = 0.08801131370663642
# Max accuracy for batch 689 = 0.75 at d = 0.03250042349100113
# Max accuracy for batch 690 = 0.75 at d = 0.1579629321396352
# Max accuracy for batch 691 = 0.5833333333333333 at d = 0.09336071896553044
# Max accuracy for batch 692 = 0.9166666666666667 at d = 0.06501131370663643
# Max accuracy for batch 693 = 0.8 at d = 0.06111403769254686
# Max accuracy for batch 694 = 0.8333333333333333 at d = 0.06601131370663643
# Max accuracy for batch 695 = 1.0 at d = 0.16909617656469356
# Max accuracy for batch 696 = 0.8 at d = 0.04188442066311837
# Max accuracy for batch 697 = 1.0 at d = 0.10601131370663643
# Max accuracy for batch 698 = 0.7857142857142857 at d = 0.09442227286100391
# Max accuracy for batch 699 = 0.7916666666666667 at d = 0.060429559320211435
# Max accuracy for batch 700 = 0.7857142857142857 at d = 0.134927896231413
# Max accuracy for batch 701 = 0.6666666666666666 at d = 0.24872017544507996
# Max accuracy for batch 702 = 0.8571428571428572 at d = 0.08501131370663643
# Max accuracy for batch 703 = 0.5714285714285714 at d = 0.04944713041186333
# Max accuracy for batch 704 = 0.6428571428571428 at d = 0.21877808272838606
# Max accuracy for batch 705 = 0.7 at d = 0.03301131370663643
# Max accuracy for batch 706 = 0.7619047619047619 at d = 0.05801131370663643
# Max accuracy for batch 707 = 1.0 at d = 0.07173173546791078
# Max accuracy for batch 708 = 0.9166666666666667 at d = 0.10501249328255657
# Max accuracy for batch 709 = 0.6666666666666667 at d = 0.11825810545682913
# Max accuracy for batch 710 = 1.0 at d = 0.05207519605755806
# Max accuracy for batch 711 = 0.8333333333333333 at d = 0.16524464571475994
# Max accuracy for batch 712 = 0.75 at d = 0.17318557789921774
# Max accuracy for batch 713 = 0.75 at d = 0.12277064010500915
# Max accuracy for batch 714 = 0.7916666666666667 at d = 0.07371416273713116
# Max accuracy for batch 715 = 0.5 at d = 0.34457510453462625
# Max accuracy for batch 716 = 0.7 at d = 0.09310629352927213
# Max accuracy for batch 717 = 0.6000000000000001 at d = 0.09975881861150271
# Max accuracy for batch 718 = 0.5 at d = 0.10369536924362188
# Max accuracy for batch 719 = 0.7857142857142857 at d = 0.15285866081714639
# Max accuracy for batch 720 = 0.7 at d = 0.09245399674028165
# Max accuracy for batch 721 = 0.75 at d = 0.04901131370663643
# Max accuracy for batch 722 = 0.9166666666666667 at d = 0.10132102325558667
# Max accuracy for batch 723 = 0.7 at d = 0.08577483224868776
# Max accuracy for batch 724 = 0.5 at d = 0.05877687898278239
# Max accuracy for batch 725 = 0.75 at d = 0.11911453348398215
# Max accuracy for batch 726 = 0.7916666666666667 at d = 0.09595705905556684
# Max accuracy for batch 727 = 0.9166666666666667 at d = 0.1042520233839751
# Max accuracy for batch 728 = 0.9166666666666667 at d = 0.10659233438968663
# Max accuracy for batch 729 = 0.7916666666666667 at d = 0.10424223195016391
# Max accuracy for batch 730 = 0.8 at d = 0.07813654211163523
# Max accuracy for batch 731 = 0.8333333333333333 at d = 0.1323820114135743
# Max accuracy for batch 732 = 0.5625 at d = 0.04208244010806084
# Max accuracy for batch 733 = 0.7916666666666667 at d = 0.15795610389113435
# Max accuracy for batch 734 = 0.6666666666666666 at d = 0.1946399803757669
# Max accuracy for batch 735 = 0.75 at d = 0.034550823658704766
# /tmp/ipykernel_88087/2930361242.py:14: RuntimeWarning: invalid value encountered in divide
#   tpr = float(np.sum(labels[idx1] == 1)) / nsame
# Max accuracy for batch 736 = 0 at d = 0
# Avg acc across all batches=0.7674223579074327 at d=0.10732307312194281
