# %%
# Cell to import libraries
import numpy as np
import random
from PIL import Image
from PIL.ImageOps import invert
import numpy as np
from torch import Tensor
from torch.utils.data import Dataset
import pickle
import torch

# %%
# Import model functions and load the pre-trained model
from Model import SiameseConvNet, distance_metric
from torch import load
from torch.utils.data import DataLoader

device = torch.device('cpu')
model = SiameseConvNet()
model.load_state_dict(load(open('Models/model_large_epoch_20', 'rb'), map_location=device))
# Out:
# <All keys matched successfully>

# %%
# Create path for both genuine and forgery images
base_path_genuine = 'Datasets/BHSig260-Hindi/Genuine/H-S-%d-G-%s.tif'
base_path_forgery = 'Datasets/BHSig260-Hindi/Forgery/H-S-%d-F-%s.tif'

# %%
# Create test dataset. The rationale for number of samples is in the appendix of the report
test = []
n_samples_of_each_class = 5891

for _ in range(n_samples_of_each_class):
    anchor_person = random.randint(1, 160)
    if anchor_person == 123:
        continue
    anchor_sign = random.randint(1, 24)
    pos_sign = random.randint(1, 24)
    while (anchor_sign == pos_sign):
        pos_sign = random.randint(1, 24)
    neg_sign = random.randint(1, 30)
    if anchor_sign < 10:
        anchor_sign = "0" + str(anchor_sign)
    if pos_sign < 10:
        pos_sign = "0" + str(pos_sign)
    if neg_sign < 10:
        neg_sign = "0" + str(neg_sign)
    positive = [base_path_genuine % (anchor_person, anchor_sign), base_path_genuine % (anchor_person, pos_sign), 1]
    negative = [base_path_genuine % (anchor_person, anchor_sign), base_path_forgery % (anchor_person, neg_sign), 0]
    test.append(positive)
    test.append(negative)

# %%
# Preprocessing and Dataloaders
# Preprocessing involves resizing and inverting the image before binarizing with a threshold intensity of 50

def invert_image(path):
	image_file = Image.open(path) # open colour image
	image_file = image_file.convert('L').resize([220, 155])
	image_file = invert(image_file)
	image_array = np.array(image_file)
	for i in range(image_array.shape[0]):
		for j in range(image_array.shape[1]):
			if image_array[i][j]<=50:
				image_array[i][j]=0
			else:
				image_array[i][j]=255
	return image_array

def convert_to_image_tensor(image_array):
	image_array = image_array/255.0
	return Tensor(image_array).view(1, 220, 155)


with open('test_index_BHSigH.pkl', 'wb') as test_index_file:
	pickle.dump(test, test_index_file)


class TestDataset(Dataset):

	def __init__(self):
		with open('test_index_BHSigH.pkl', 'rb') as test_index_file:
			self.pairs = pickle.load(test_index_file)

	def __getitem__(self, index):
		item = self.pairs[index]
		X = convert_to_image_tensor(invert_image(item[0]))
		Y = convert_to_image_tensor(invert_image(item[1]))
		return [X, Y, item[2]]

	def __len__(self):
		return len(self.pairs)

# %%
# Compute accuracy as average of True Positive and True Negative rates

def compute_accuracy_roc(predictions, labels):
    dmax = np.max(predictions)
    dmin = np.min(predictions)
    nsame = np.sum(labels == 1)
    ndiff = np.sum(labels == 0)
    step = 0.001
    max_acc = 0

    d_optimal = 0
    for d in np.arange(dmin, dmax + step, step):
        idx1 = predictions.ravel() <= d
        idx2 = predictions.ravel() > d

        tpr = float(np.sum(labels[idx1] == 1)) / nsame
        tnr = float(np.sum(labels[idx2] == 0)) / ndiff

        acc = 0.5 * (tpr + tnr)

        if acc > max_acc:
            max_acc = acc
            d_optimal = d

    return max_acc, d_optimal

# %%
# Compute the accuracy on the test data set

batch_avg_acc = 0
batch_avg_d = 0
n_batch = 0


def test():
    model.eval()
    global batch_avg_acc, batch_avg_d, n_batch

    test_dataset = TestDataset()
    loader = DataLoader(test_dataset, batch_size=10, shuffle=True)

    for batch_index, data in enumerate(loader):
        A = data[0]
        B = data[1]
        labels = data[2].long()

        f_a, f_b = model.forward(A, B)
        dist = distance_metric(f_a, f_b)

        acc, d = compute_accuracy_roc(dist.detach().numpy(), labels.detach().numpy())
        print('Max accuracy for batch {} = {} at d = {}'.format(batch_index, acc, d))
        batch_avg_acc += acc
        batch_avg_d += d
        n_batch += 1


print('BHSigH:')
test()
print('Avg acc across all batches={} at d={}'.format(batch_avg_acc / n_batch, batch_avg_d / n_batch))
# Out:
# BHSigH:
# Max accuracy for batch 0 = 0.875 at d = 0.10864285683631902
# Max accuracy for batch 1 = 1.0 at d = 0.10864168584346778
# Max accuracy for batch 2 = 0.7 at d = 0.25012677884101886
# Max accuracy for batch 3 = 0.5952380952380952 at d = 0.11987157569825657
# Max accuracy for batch 4 = 0.7857142857142857 at d = 0.15791708318889153
# Max accuracy for batch 5 = 0.6000000000000001 at d = 0.21113630172610298
# Max accuracy for batch 6 = 0.8571428571428572 at d = 0.12315853628516205
# Max accuracy for batch 7 = 0.9285714285714286 at d = 0.1158769629001618
# Max accuracy for batch 8 = 0.9 at d = 0.09723830856382853
# Max accuracy for batch 9 = 0.6666666666666666 at d = 0.17061725389957438
# Max accuracy for batch 10 = 0.8333333333333333 at d = 0.13238222539424904
# Max accuracy for batch 11 = 0.6666666666666667 at d = 0.14947868043184287
# Max accuracy for batch 12 = 0.9285714285714286 at d = 0.11560439869761474
# Max accuracy for batch 13 = 0.7 at d = 0.03963796225190164
# Max accuracy for batch 14 = 0.6666666666666666 at d = 0.04465542733669281
# Max accuracy for batch 15 = 0.625 at d = 0.03374581554532052
# Max accuracy for batch 16 = 0.6666666666666667 at d = 0.15772856903076182
# Max accuracy for batch 17 = 1.0 at d = 0.060582562357187286
# Max accuracy for batch 18 = 0.9285714285714286 at d = 0.11973090419173249
# Max accuracy for batch 19 = 0.8571428571428572 at d = 0.19140081492066396
# Max accuracy for batch 20 = 0.7 at d = 0.07080488868057733
# Max accuracy for batch 21 = 0.5714285714285714 at d = 0.10035089403390884
# Max accuracy for batch 22 = 0.5833333333333334 at d = 0.034740760922431946
# Max accuracy for batch 23 = 0.8333333333333333 at d = 0.0794865524321795
# Max accuracy for batch 24 = 0.8 at d = 0.06516873603314166
# Max accuracy for batch 25 = 0.8333333333333333 at d = 0.13389820039272315
# Max accuracy for batch 26 = 0.875 at d = 0.12095063466951252
# Max accuracy for batch 27 = 0.6904761904761905 at d = 0.10084789413213735
# Max accuracy for batch 28 = 0.8 at d = 0.16747697240114223
# Max accuracy for batch 29 = 0.8333333333333333 at d = 0.05862511372566226
# Max accuracy for batch 30 = 0.9375 at d = 0.1575401594042779
# Max accuracy for batch 31 = 0.6904761904761905 at d = 0.12104067035019406
# Max accuracy for batch 32 = 0.875 at d = 0.15712194782495503
# Max accuracy for batch 33 = 0.7916666666666667 at d = 0.08048741702735429
# Max accuracy for batch 34 = 0.6666666666666666 at d = 0.029185288369655615
# Max accuracy for batch 35 = 0.75 at d = 0.03926299139857292
# Max accuracy for batch 36 = 0.7083333333333333 at d = 0.08937570580840115
# Max accuracy for batch 37 = 0.7857142857142857 at d = 0.10115586920082575
# Max accuracy for batch 38 = 0.6904761904761905 at d = 0.11402624249458315
# Max accuracy for batch 39 = 0.625 at d = 0.14537169641256342
# Max accuracy for batch 40 = 0.875 at d = 0.0921965803802014
# Max accuracy for batch 41 = 0.75 at d = 0.08049327936768536
# Max accuracy for batch 42 = 0.75 at d = 0.04007795596122743
# Max accuracy for batch 43 = 0.9285714285714286 at d = 0.0831731096208096
# Max accuracy for batch 44 = 0.6666666666666667 at d = 0.10659533324837689
# Max accuracy for batch 45 = 0.8 at d = 0.06083540630340578
# Max accuracy for batch 46 = 0.9444444444444444 at d = 0.06934234067797662
# Max accuracy for batch 47 = 0.9166666666666667 at d = 0.2190582840144636
# Max accuracy for batch 48 = 0.8333333333333333 at d = 0.04345138305425644
# Max accuracy for batch 49 = 0.75 at d = 0.09274607312679295
# Max accuracy for batch 50 = 0.7 at d = 0.11115265595912938
# Max accuracy for batch 51 = 0.8 at d = 0.13089746880531317
# Max accuracy for batch 52 = 0.6428571428571428 at d = 0.04434074839949609
# Max accuracy for batch 53 = 0.9166666666666667 at d = 0.11608852767944344
# Max accuracy for batch 54 = 0.7083333333333333 at d = 0.10851331403851516
# Max accuracy for batch 55 = 0.9375 at d = 0.2054393608272077
# Max accuracy for batch 56 = 0.7857142857142857 at d = 0.2071666214317085
# Max accuracy for batch 57 = 0.9166666666666667 at d = 0.08944074833393101
# Max accuracy for batch 58 = 1.0 at d = 0.13768527902662764
# Max accuracy for batch 59 = 0.8 at d = 0.09821346759796146
# Max accuracy for batch 60 = 0.9 at d = 0.18557318925857558
# Max accuracy for batch 61 = 0.9166666666666667 at d = 0.11008138677477841
# Max accuracy for batch 62 = 0.75 at d = 0.15122522461414345
# Max accuracy for batch 63 = 0.8 at d = 0.07981050613522533
# Max accuracy for batch 64 = 0.9 at d = 0.13466089716553697
# Max accuracy for batch 65 = 0.75 at d = 0.09524839834868915
# Max accuracy for batch 66 = 0.8125 at d = 0.12924639904499058
# Max accuracy for batch 67 = 1.0 at d = 0.07361347508430482
# Max accuracy for batch 68 = 0.8 at d = 0.11207666480541234
# Max accuracy for batch 69 = 0.75 at d = 0.056610226690769205
# Max accuracy for batch 70 = 0.9166666666666667 at d = 0.08572388464212422
# Max accuracy for batch 71 = 0.7857142857142857 at d = 0.08059774619340898
# Max accuracy for batch 72 = 0.7916666666666667 at d = 0.09810662266612058
# Max accuracy for batch 73 = 1.0 at d = 0.10108768066763885
# Max accuracy for batch 74 = 0.75 at d = 0.15394803994894035
# Max accuracy for batch 75 = 0.8333333333333333 at d = 0.12923006179928787
# Max accuracy for batch 76 = 0.6000000000000001 at d = 0.1257170823216439
# Max accuracy for batch 77 = 0.8 at d = 0.10065727683901793
# Max accuracy for batch 78 = 0.8 at d = 0.040316469699144375
# Max accuracy for batch 79 = 0.75 at d = 0.0736281855553389
# Max accuracy for batch 80 = 0.6 at d = 0.040447644889354706
# Max accuracy for batch 81 = 0.7619047619047619 at d = 0.14075814592838298
# Max accuracy for batch 82 = 0.6666666666666666 at d = 0.04210877989232542
# Max accuracy for batch 83 = 0.5625 at d = 0.04043534770607948
# Max accuracy for batch 84 = 0.9166666666666667 at d = 0.08418253257870678
# Max accuracy for batch 85 = 0.9166666666666667 at d = 0.14282869392633446
# Max accuracy for batch 86 = 0.9375 at d = 0.11819394922256476
# Max accuracy for batch 87 = 0.6666666666666666 at d = 0.043188974261283875
# Max accuracy for batch 88 = 0.7 at d = 0.02761055326461792
# Max accuracy for batch 89 = 0.9 at d = 0.07204937334358696
# Max accuracy for batch 90 = 0.7 at d = 0.11959141045808797
# Max accuracy for batch 91 = 0.875 at d = 0.1487537468969823
# Max accuracy for batch 92 = 0.5625 at d = 0.036167774349451065
# Max accuracy for batch 93 = 0.8 at d = 0.08068828877806666
# Max accuracy for batch 94 = 0.6875 at d = 0.10539501976966859
# Max accuracy for batch 95 = 1.0 at d = 0.11737407062947758
# Max accuracy for batch 96 = 0.8333333333333333 at d = 0.10101762908697132
# Max accuracy for batch 97 = 1.0 at d = 0.1020615845173598
# Max accuracy for batch 98 = 0.6666666666666667 at d = 0.04862372896820307
# Max accuracy for batch 99 = 0.5952380952380952 at d = 0.22438811606168763
# Max accuracy for batch 100 = 0.75 at d = 0.19160720837116252
# Max accuracy for batch 101 = 0.75 at d = 0.07950213778018955
# Max accuracy for batch 102 = 0.8333333333333333 at d = 0.03681311680376531
# Max accuracy for batch 103 = 0.5625 at d = 0.19611693125963225
# Max accuracy for batch 104 = 0.7 at d = 0.053925015866756465
# Max accuracy for batch 105 = 0.7 at d = 0.04593001273274422
# Max accuracy for batch 106 = 0.8 at d = 0.149950514599681
# Max accuracy for batch 107 = 0.75 at d = 0.03814040124416351
# Max accuracy for batch 108 = 1.0 at d = 0.08111791074275976
# Max accuracy for batch 109 = 0.7916666666666667 at d = 0.11061068490147596
# Max accuracy for batch 110 = 0.7083333333333333 at d = 0.08215839165449146
# Max accuracy for batch 111 = 1.0 at d = 0.04336930438876152
# Max accuracy for batch 112 = 0.7 at d = 0.05612242671847345
# Max accuracy for batch 113 = 0.6666666666666667 at d = 0.19188630241155635
# Max accuracy for batch 114 = 0.8 at d = 0.2253356589376928
# Max accuracy for batch 115 = 0.7083333333333333 at d = 0.05609018291532997
# Max accuracy for batch 116 = 0.6666666666666667 at d = 0.0962150086164475
# Max accuracy for batch 117 = 0.7 at d = 0.028633783139288438
# Max accuracy for batch 118 = 0.8 at d = 0.08447268125414853
# Max accuracy for batch 119 = 0.8571428571428572 at d = 0.14017833751440056
# Max accuracy for batch 120 = 0.7857142857142857 at d = 0.06470047700405124
# Max accuracy for batch 121 = 0.6666666666666666 at d = 0.15933090372383607
# Max accuracy for batch 122 = 0.75 at d = 0.0874158071428538
# Max accuracy for batch 123 = 0.5833333333333334 at d = 0.02100108563899994
# Max accuracy for batch 124 = 0.5833333333333334 at d = 0.03583189845085144
# Max accuracy for batch 125 = 0.7083333333333333 at d = 0.09508522909879691
# Max accuracy for batch 126 = 0.875 at d = 0.09267380852997309
# Max accuracy for batch 127 = 0.875 at d = 0.13605827322602282
# Max accuracy for batch 128 = 0.625 at d = 0.18805338454246534
# Max accuracy for batch 129 = 0.6000000000000001 at d = 0.10231455498933795
# Max accuracy for batch 130 = 0.7 at d = 0.10493787577748304
# Max accuracy for batch 131 = 0.9 at d = 0.1515458740592004
# Max accuracy for batch 132 = 0.7916666666666667 at d = 0.09952356702089316
# /tmp/ipykernel_119063/2930361242.py:15: RuntimeWarning: invalid value encountered in divide
#   tnr = float(np.sum(labels[idx2] == 0)) / ndiff
# Max accuracy for batch 133 = 0 at d = 0
# Max accuracy for batch 134 = 0.8333333333333333 at d = 0.04259139683842661
# Max accuracy for batch 135 = 0.8 at d = 0.1284208592176438
# Max accuracy for batch 136 = 0.9285714285714286 at d = 0.09676772052049643
# Max accuracy for batch 137 = 0.8333333333333333 at d = 0.06519763551652435
# Max accuracy for batch 138 = 0.625 at d = 0.0674542784690857
# Max accuracy for batch 139 = 0.7619047619047619 at d = 0.06158555376529695
# Max accuracy for batch 140 = 1.0 at d = 0.06397225594520572
# Max accuracy for batch 141 = 0.6000000000000001 at d = 0.0840392164885998
# Max accuracy for batch 142 = 0.75 at d = 0.32064350274205233
# Max accuracy for batch 143 = 0.75 at d = 0.08007605654001237
# Max accuracy for batch 144 = 0.7857142857142857 at d = 0.04594223174452783
# Max accuracy for batch 145 = 0.75 at d = 0.13580314594507226
# Max accuracy for batch 146 = 0.9166666666666667 at d = 0.0987978822290898
# Max accuracy for batch 147 = 0.6666666666666667 at d = 0.1685188466459514
# Max accuracy for batch 148 = 0.7 at d = 0.07623865643143657
# Max accuracy for batch 149 = 0.8333333333333333 at d = 0.09780100331455477
# Max accuracy for batch 150 = 0.6000000000000001 at d = 0.05219674587249756
# Max accuracy for batch 151 = 0.7142857142857143 at d = 0.10904398962855344
# Max accuracy for batch 152 = 0.6 at d = 0.030437268316745758
# Max accuracy for batch 153 = 0.75 at d = 0.2082219219207765
# Max accuracy for batch 154 = 0.8571428571428572 at d = 0.0633164979647845
# Max accuracy for batch 155 = 0.7083333333333333 at d = 0.15411394602060324
# Max accuracy for batch 156 = 0.9444444444444444 at d = 0.12819543600082406
# Max accuracy for batch 157 = 0.7916666666666667 at d = 0.11289909918606289
# Max accuracy for batch 158 = 0.6666666666666667 at d = 0.12562714195251468
# Max accuracy for batch 159 = 0.8 at d = 0.17484148827195178
# Max accuracy for batch 160 = 0.5833333333333334 at d = 0.031826745718717575
# Max accuracy for batch 161 = 0.9 at d = 0.10796463717520244
# Max accuracy for batch 162 = 0.6000000000000001 at d = 0.06754520033299927
# Max accuracy for batch 163 = 0.875 at d = 0.1317497995197774
# Max accuracy for batch 164 = 0.9166666666666667 at d = 0.1364670990705491
# Max accuracy for batch 165 = 0.6875 at d = 0.05896131294965745
# Max accuracy for batch 166 = 0.9 at d = 0.11991304448246964
# Max accuracy for batch 167 = 0.8 at d = 0.2513046277165415
# Max accuracy for batch 168 = 0.7916666666666667 at d = 0.16179428151249897
# Max accuracy for batch 169 = 0.7222222222222222 at d = 0.05040409153699876
# Max accuracy for batch 170 = 0.875 at d = 0.13734515750408183
# Max accuracy for batch 171 = 0.7916666666666667 at d = 0.0911321141123772
# Max accuracy for batch 172 = 0.7083333333333333 at d = 0.17168392476439487
# Max accuracy for batch 173 = 0.8333333333333333 at d = 0.1686470800712706
# Max accuracy for batch 174 = 0.8 at d = 0.12438294234871872
# Max accuracy for batch 175 = 0.6666666666666666 at d = 0.284197688996792
# Max accuracy for batch 176 = 0.7 at d = 0.12062063169479376
# Max accuracy for batch 177 = 0.8125 at d = 0.14873810428380974
# Max accuracy for batch 178 = 0.625 at d = 0.2157467277348043
# Max accuracy for batch 179 = 0.8571428571428572 at d = 0.0926096005737782
# Max accuracy for batch 180 = 0.7142857142857143 at d = 0.0683572899401188
# Max accuracy for batch 181 = 0.9 at d = 0.1770182715505363
# Max accuracy for batch 182 = 0.9 at d = 0.13065913088619718
# Max accuracy for batch 183 = 0.625 at d = 0.06920499354600906
# Max accuracy for batch 184 = 0.8125 at d = 0.1414704598188401
# Max accuracy for batch 185 = 0.8333333333333333 at d = 0.21052213135361686
# Max accuracy for batch 186 = 0.6666666666666666 at d = 0.03266390500962735
# Max accuracy for batch 187 = 0.7142857142857143 at d = 0.21607820264995115
# Max accuracy for batch 188 = 0.5952380952380952 at d = 0.22687592419981972
# Max accuracy for batch 189 = 1.0 at d = 0.17933901804685604
# Max accuracy for batch 190 = 0.7916666666666667 at d = 0.097432835161686
# Max accuracy for batch 191 = 0.8571428571428572 at d = 0.09976694019138821
# Max accuracy for batch 192 = 0.6666666666666666 at d = 0.16785693150758751
# Max accuracy for batch 193 = 0.7083333333333333 at d = 0.10501413044333463
# Max accuracy for batch 194 = 0.9 at d = 0.055593694180250175
# Max accuracy for batch 195 = 0.625 at d = 0.03412048891186714
# Max accuracy for batch 196 = 0.9 at d = 0.20960429739952102
# Max accuracy for batch 197 = 0.7 at d = 0.04805725035071373
# Max accuracy for batch 198 = 0.9 at d = 0.09451210857927805
# Max accuracy for batch 199 = 0.7857142857142857 at d = 0.07454144999384882
# Max accuracy for batch 200 = 1.0 at d = 0.11730323681235322
# Max accuracy for batch 201 = 0.625 at d = 0.10091775110363965
# Max accuracy for batch 202 = 0.7857142857142857 at d = 0.10559792715311056
# Max accuracy for batch 203 = 0.7857142857142857 at d = 0.06283643317222598
# Max accuracy for batch 204 = 0.5625 at d = 0.09810421717166906
# Max accuracy for batch 205 = 0.5714285714285714 at d = 0.03723146393895149
# Max accuracy for batch 206 = 0.7916666666666667 at d = 0.21227715697884575
# Max accuracy for batch 207 = 0.7857142857142857 at d = 0.14472672653198249
# Max accuracy for batch 208 = 0.7916666666666667 at d = 0.11827766487002378
# Max accuracy for batch 209 = 0.6666666666666666 at d = 0.29790252721309685
# Max accuracy for batch 210 = 0.7 at d = 0.06202897024154663
# Max accuracy for batch 211 = 0.625 at d = 0.0426015742123127
# Max accuracy for batch 212 = 0.7142857142857143 at d = 0.1487802923321725
# Max accuracy for batch 213 = 0.7083333333333333 at d = 0.07648567156493669
# Max accuracy for batch 214 = 0.6000000000000001 at d = 0.18072902476787578
# Max accuracy for batch 215 = 0.5 at d = 0.2708729073703291
# Max accuracy for batch 216 = 1.0 at d = 0.05741547152400017
# Max accuracy for batch 217 = 0.9444444444444444 at d = 0.06583602359890939
# Max accuracy for batch 218 = 0.8333333333333333 at d = 0.07393274408578876
# Max accuracy for batch 219 = 0.875 at d = 0.09811149945855147
# Max accuracy for batch 220 = 0.75 at d = 0.11180488868057736
# Max accuracy for batch 221 = 0.7 at d = 0.021287250280380254
# Max accuracy for batch 222 = 0.6666666666666667 at d = 0.1569458831846715
# Max accuracy for batch 223 = 0.875 at d = 0.1832098240554334
# Max accuracy for batch 224 = 0.8333333333333333 at d = 0.07499755454063417
# Max accuracy for batch 225 = 0.8333333333333333 at d = 0.17633693769574177
# Max accuracy for batch 226 = 0.8333333333333333 at d = 0.10278007531166078
# Max accuracy for batch 227 = 0.9375 at d = 0.10767615184187895
# Max accuracy for batch 228 = 0.7916666666666667 at d = 0.05542390778660777
# Max accuracy for batch 229 = 0.7857142857142857 at d = 0.20612478269636647
# Max accuracy for batch 230 = 1.0 at d = 0.21696876582503333
# Max accuracy for batch 231 = 0.9 at d = 0.09276587074995046
# Max accuracy for batch 232 = 0.8333333333333333 at d = 0.08723591050505641
# Max accuracy for batch 233 = 0.8 at d = 0.05475129441171889
# Max accuracy for batch 234 = 0.9 at d = 0.1697054237909615
# Max accuracy for batch 235 = 0.625 at d = 0.13204454940557486
# Max accuracy for batch 236 = 0.75 at d = 0.03552459892630577
# Max accuracy for batch 237 = 0.7 at d = 0.03688649192452431
# Max accuracy for batch 238 = 0.9375 at d = 0.12967783325910576
# Max accuracy for batch 239 = 0.9166666666666667 at d = 0.17416622591018682
# Max accuracy for batch 240 = 0.7 at d = 0.14795158505439765
# Max accuracy for batch 241 = 0.7 at d = 0.04281086826324465
# Max accuracy for batch 242 = 0.8 at d = 0.10070212811231616
# Max accuracy for batch 243 = 0.7 at d = 0.2708314125537874
# Max accuracy for batch 244 = 0 at d = 0
# Max accuracy for batch 245 = 0.875 at d = 0.1362012444436551
# Max accuracy for batch 246 = 0.8571428571428572 at d = 0.10591245281696327
# Max accuracy for batch 247 = 0.8 at d = 0.03955083614587784
# Max accuracy for batch 248 = 0.7 at d = 0.04839781200885773
# Max accuracy for batch 249 = 0.9166666666666667 at d = 0.09720908683352172
# Max accuracy for batch 250 = 0.8 at d = 0.16280653256177913
# Max accuracy for batch 251 = 0.6666666666666667 at d = 0.11669683212041859
# Max accuracy for batch 252 = 0.9166666666666667 at d = 0.12356009677052504
# Max accuracy for batch 253 = 0.5 at d = 0.24958746850490587
# Max accuracy for batch 254 = 0.75 at d = 0.08472457271814349
# Max accuracy for batch 255 = 1.0 at d = 0.04898227143287659
# Max accuracy for batch 256 = 0.9375 at d = 0.05858856478333474
# Max accuracy for batch 257 = 0.75 at d = 0.06161323371529581
# Max accuracy for batch 258 = 1.0 at d = 0.05180488868057731
# Max accuracy for batch 259 = 0.7083333333333333 at d = 0.19478487071394934
# Max accuracy for batch 260 = 0.8 at d = 0.06111051751673224
# Max accuracy for batch 261 = 0.9 at d = 0.10251584920287138
# Max accuracy for batch 262 = 0.5833333333333334 at d = 0.03908140957355499
# Max accuracy for batch 263 = 0.75 at d = 0.2958510372936728
# Max accuracy for batch 264 = 0.8 at d = 0.08531557145714763
# Max accuracy for batch 265 = 0.7 at d = 0.1185373417139054
# Max accuracy for batch 266 = 0.75 at d = 0.0739284699261189
# Max accuracy for batch 267 = 0.6666666666666666 at d = 0.027456781610846526
# Max accuracy for batch 268 = 0.6666666666666666 at d = 0.21768989878892908
# Max accuracy for batch 269 = 0.6666666666666667 at d = 0.15414285829663288
# Max accuracy for batch 270 = 0.8 at d = 0.11093967646360403
# Max accuracy for batch 271 = 0.6666666666666666 at d = 0.12484635639190678
# Max accuracy for batch 272 = 0.6875 at d = 0.16722129267454156
# Max accuracy for batch 273 = 0.6000000000000001 at d = 0.06716270039975647
# Max accuracy for batch 274 = 0.75 at d = 0.04038229070603849
# Max accuracy for batch 275 = 0.7857142857142857 at d = 0.07175357908383012
# Max accuracy for batch 276 = 0.8571428571428572 at d = 0.07035443401336672
# Max accuracy for batch 277 = 0.8 at d = 0.0984714657068253
# Max accuracy for batch 278 = 0.7619047619047619 at d = 0.21254866078495993
# Max accuracy for batch 279 = 1.0 at d = 0.14096908912062656
# Max accuracy for batch 280 = 0.9285714285714286 at d = 0.11404926815629013
# Max accuracy for batch 281 = 0.6666666666666667 at d = 0.05728136903047565
# Max accuracy for batch 282 = 0.75 at d = 0.09230407142639163
# Max accuracy for batch 283 = 0.7142857142857143 at d = 0.2267221004366876
# Max accuracy for batch 284 = 0.7777777777777778 at d = 0.09863235118985181
# Max accuracy for batch 285 = 0.75 at d = 0.2870665419995787
# Max accuracy for batch 286 = 0.9 at d = 0.14847255564481032
# Max accuracy for batch 287 = 0.625 at d = 0.21884454137086884
# Max accuracy for batch 288 = 0.7916666666666667 at d = 0.06816879782080654
# Max accuracy for batch 289 = 0.7 at d = 0.24621866844594498
# Max accuracy for batch 290 = 0.8333333333333333 at d = 0.10273236307501799
# Max accuracy for batch 291 = 0.9 at d = 0.18423196202516567
# Max accuracy for batch 292 = 0.875 at d = 0.2193101489543916
# Max accuracy for batch 293 = 0.875 at d = 0.08454334206879144
# Max accuracy for batch 294 = 0.6666666666666666 at d = 0.04948339781165123
# Max accuracy for batch 295 = 1.0 at d = 0.07502172741293911
# Max accuracy for batch 296 = 0.7142857142857143 at d = 0.250587781250477
# Max accuracy for batch 297 = 0.5 at d = 0.23671420824527756
# Max accuracy for batch 298 = 0.6666666666666666 at d = 0.06538517773151398
# Max accuracy for batch 299 = 0.625 at d = 0.06356415152549744
# Max accuracy for batch 300 = 0.75 at d = 0.026796142682433133
# Max accuracy for batch 301 = 0.625 at d = 0.08662879595160489
# Max accuracy for batch 302 = 0.9166666666666667 at d = 0.1350820781402291
# Max accuracy for batch 303 = 0.8333333333333333 at d = 0.12107525260746488
# Max accuracy for batch 304 = 0.8333333333333333 at d = 0.03835974080860616
# Max accuracy for batch 305 = 0.6875 at d = 0.053779253751039535
# Max accuracy for batch 306 = 0.75 at d = 0.05447663071751596
# Max accuracy for batch 307 = 0.6666666666666666 at d = 0.18706324812769903
# Max accuracy for batch 308 = 0.5833333333333334 at d = 0.04088142514228821
# Max accuracy for batch 309 = 0.9285714285714286 at d = 0.10316655305027966
# Max accuracy for batch 310 = 0.7 at d = 0.043099168315529846
# Max accuracy for batch 311 = 0.7916666666666667 at d = 0.095604034870863
# Max accuracy for batch 312 = 0.625 at d = 0.11912739817798146
# Max accuracy for batch 313 = 0.7916666666666667 at d = 0.10791932728886611
# Max accuracy for batch 314 = 0.75 at d = 0.07927904867380864
# Max accuracy for batch 315 = 0.5476190476190476 at d = 0.1787521460056306
# Max accuracy for batch 316 = 0.7 at d = 0.09999079687893397
# Max accuracy for batch 317 = 0.625 at d = 0.055471356958150864
# Max accuracy for batch 318 = 0.75 at d = 0.04761973358690741
# Max accuracy for batch 319 = 0.8 at d = 0.08937927418947222
# Max accuracy for batch 320 = 0.6428571428571428 at d = 0.06959023612737658
# Max accuracy for batch 321 = 0.7 at d = 0.32054072779417064
# Max accuracy for batch 322 = 0.8 at d = 0.051831496998667737
# Max accuracy for batch 323 = 1.0 at d = 0.0729133030623198
# Max accuracy for batch 324 = 0.875 at d = 0.17934301030635846
# Max accuracy for batch 325 = 1.0 at d = 0.04789955914020538
# Max accuracy for batch 326 = 0.6875 at d = 0.061795952349901206
# Max accuracy for batch 327 = 0.7 at d = 0.08398241129517559
# Max accuracy for batch 328 = 0.875 at d = 0.14211030161380778
# Max accuracy for batch 329 = 0.5833333333333334 at d = 0.06079647317528725
# Max accuracy for batch 330 = 0.7857142857142857 at d = 0.1268033768534661
# Max accuracy for batch 331 = 1.0 at d = 0.14088988330960284
# Max accuracy for batch 332 = 0.5833333333333334 at d = 0.06855154037475586
# Max accuracy for batch 333 = 0.7 at d = 0.15870202255249033
# Max accuracy for batch 334 = 0.9 at d = 0.15326689369976532
# Max accuracy for batch 335 = 0.7142857142857143 at d = 0.2255122633874418
# Max accuracy for batch 336 = 0.8125 at d = 0.13440993674099455
# Max accuracy for batch 337 = 0.8333333333333333 at d = 0.1039618134982884
# Max accuracy for batch 338 = 0.6000000000000001 at d = 0.052433441072702425
# Max accuracy for batch 339 = 1.0 at d = 0.22158880528807656
# Max accuracy for batch 340 = 0.8 at d = 0.1229419851005078
# Max accuracy for batch 341 = 0.8571428571428572 at d = 0.11217959907650954
# Max accuracy for batch 342 = 0.7142857142857143 at d = 0.04052326330542566
# Max accuracy for batch 343 = 0.6000000000000001 at d = 0.06772887954115869
# Max accuracy for batch 344 = 0.75 at d = 0.04328960120677949
# Max accuracy for batch 345 = 0.8571428571428572 at d = 0.10776875571906575
# Max accuracy for batch 346 = 0.7083333333333333 at d = 0.09674521127343183
# Max accuracy for batch 347 = 0.75 at d = 0.10246720540523535
# Max accuracy for batch 348 = 0.8125 at d = 0.05816845920681957
# Max accuracy for batch 349 = 0.75 at d = 0.05229818245768547
# Max accuracy for batch 350 = 0.7 at d = 0.11164717960357673
# Max accuracy for batch 351 = 0.8 at d = 0.07995544315874581
# Max accuracy for batch 352 = 0.75 at d = 0.21640116980671897
# Max accuracy for batch 353 = 0.6 at d = 0.037725869566202164
# Max accuracy for batch 354 = 0.7619047619047619 at d = 0.20333942142128958
# Max accuracy for batch 355 = 0.7916666666666667 at d = 0.08780268193781382
# Max accuracy for batch 356 = 0.7083333333333333 at d = 0.14207775397598754
# Max accuracy for batch 357 = 0.75 at d = 0.029782323002815247
# Max accuracy for batch 358 = 0.7857142857142857 at d = 0.11391162071377048
# Max accuracy for batch 359 = 0.8 at d = 0.0373303965330124
# Max accuracy for batch 360 = 0.7916666666666667 at d = 0.09880653256177907
# Max accuracy for batch 361 = 1.0 at d = 0.11614577281475069
# Max accuracy for batch 362 = 0.6904761904761905 at d = 0.15914346522092826
# Max accuracy for batch 363 = 0.625 at d = 0.05099589148163797
# Max accuracy for batch 364 = 0.7 at d = 0.06590511634945873
# Max accuracy for batch 365 = 0.75 at d = 0.10405185778439052
# Max accuracy for batch 366 = 0.8571428571428572 at d = 0.11467389732599265
# Max accuracy for batch 367 = 0.7 at d = 0.054304367437958745
# Max accuracy for batch 368 = 0.8 at d = 0.08095584860444072
# Max accuracy for batch 369 = 1.0 at d = 0.04663356405496599
# Max accuracy for batch 370 = 0.6666666666666666 at d = 0.053689559102058415
# Max accuracy for batch 371 = 0.6000000000000001 at d = 0.16800345993041998
# Max accuracy for batch 372 = 0.625 at d = 0.07534975558519363
# Max accuracy for batch 373 = 1.0 at d = 0.0785300998091698
# Max accuracy for batch 374 = 0.75 at d = 0.08302040892839435
# Max accuracy for batch 375 = 0.8571428571428572 at d = 0.15639526867866527
# Max accuracy for batch 376 = 0.5 at d = 0.08666097494959835
# Max accuracy for batch 377 = 0.7857142857142857 at d = 0.10140764343738562
# Max accuracy for batch 378 = 1.0 at d = 0.2417345740944149
# Max accuracy for batch 379 = 0.9 at d = 0.06756308647990228
# Max accuracy for batch 380 = 0.5625 at d = 0.20788831216096892
# Max accuracy for batch 381 = 0.6875 at d = 0.04399111258983612
# Max accuracy for batch 382 = 0.9 at d = 0.1122446618825198
# Max accuracy for batch 383 = 0.8 at d = 0.08697111561894422
# Max accuracy for batch 384 = 0.9 at d = 0.08940282636880881
# Max accuracy for batch 385 = 1.0 at d = 0.14522211028635512
# Max accuracy for batch 386 = 0.9375 at d = 0.1491792734265328
# Max accuracy for batch 387 = 0.8571428571428572 at d = 0.09348036286234862
# Max accuracy for batch 388 = 0.625 at d = 0.06351805478334427
# Max accuracy for batch 389 = 1.0 at d = 0.11454223510622985
# Max accuracy for batch 390 = 0.9 at d = 0.12952810606360443
# Max accuracy for batch 391 = 0.875 at d = 0.132009456858039
# Max accuracy for batch 392 = 0.5 at d = 0.2832260949015619
# Max accuracy for batch 393 = 1.0 at d = 0.063579864859581
# Max accuracy for batch 394 = 0.7083333333333333 at d = 0.09816599251329905
# Max accuracy for batch 395 = 0.8 at d = 0.1496641445159913
# Max accuracy for batch 396 = 0.8333333333333333 at d = 0.09286671386659151
# Max accuracy for batch 397 = 0.6666666666666667 at d = 0.0672611368596554
# Max accuracy for batch 398 = 0.75 at d = 0.15501909095048916
# Max accuracy for batch 399 = 0.6666666666666667 at d = 0.1254146801829339
# Max accuracy for batch 400 = 0.6904761904761905 at d = 0.11595506170392045
# Max accuracy for batch 401 = 0.7 at d = 0.03628369799256326
# Max accuracy for batch 402 = 0.7 at d = 0.050703938722610475
# Max accuracy for batch 403 = 0.875 at d = 0.08321187198162083
# Max accuracy for batch 404 = 0.6 at d = 0.030841931700706482
# Max accuracy for batch 405 = 0.7916666666666667 at d = 0.09787106516957289
# Max accuracy for batch 406 = 0.6666666666666667 at d = 0.0894662570357323
# Max accuracy for batch 407 = 1.0 at d = 0.07795473333448177
# Max accuracy for batch 408 = 0.5833333333333334 at d = 0.2660528326034547
# Max accuracy for batch 409 = 0.8333333333333333 at d = 0.11032901504635817
# Max accuracy for batch 410 = 0.6904761904761905 at d = 0.11538152986764916
# Max accuracy for batch 411 = 0.8333333333333333 at d = 0.13207114046812063
# Max accuracy for batch 412 = 0.75 at d = 0.06198488144576553
# Max accuracy for batch 413 = 0.7916666666666667 at d = 0.16545799744129186
# Max accuracy for batch 414 = 0.7 at d = 0.15147602313756947
# Max accuracy for batch 415 = 0.6666666666666667 at d = 0.06865165898203851
# Max accuracy for batch 416 = 0.9166666666666667 at d = 0.065683416441083
# Max accuracy for batch 417 = 0.6666666666666666 at d = 0.21224839979410182
# Max accuracy for batch 418 = 0.8571428571428572 at d = 0.1707126769423486
# Max accuracy for batch 419 = 0.8571428571428572 at d = 0.07746415729820733
# Max accuracy for batch 420 = 0.8 at d = 0.07376034241914753
# Max accuracy for batch 421 = 0.9285714285714286 at d = 0.19718427705764785
# Max accuracy for batch 422 = 0.75 at d = 0.15290686099231254
# Max accuracy for batch 423 = 0 at d = 0
# Max accuracy for batch 424 = 0.7 at d = 0.0632111518532038
# Max accuracy for batch 425 = 0.9375 at d = 0.16620298343896878
# Max accuracy for batch 426 = 1.0 at d = 0.12321600875258454
# Max accuracy for batch 427 = 0.75 at d = 0.056302980095148114
# Max accuracy for batch 428 = 0.7857142857142857 at d = 0.11833926770091063
# Max accuracy for batch 429 = 0.9375 at d = 0.10826740777492527
# Max accuracy for batch 430 = 0.75 at d = 0.07941677471995356
# Max accuracy for batch 431 = 0.6666666666666666 at d = 0.2977413669973614
# Max accuracy for batch 432 = 0.9166666666666667 at d = 0.13748248709738264
# Max accuracy for batch 433 = 0.8 at d = 0.10362502464652068
# Max accuracy for batch 434 = 0.8 at d = 0.07135861620306971
# Max accuracy for batch 435 = 0.5 at d = 0.1107909065485001
# Max accuracy for batch 436 = 0.8 at d = 0.07410200899839403
# Max accuracy for batch 437 = 1.0 at d = 0.09333612734079366
# Max accuracy for batch 438 = 0.9166666666666667 at d = 0.09847918955981738
# Max accuracy for batch 439 = 0.9 at d = 0.11644834485650069
# Max accuracy for batch 440 = 0.7 at d = 0.028091507419943818
# Max accuracy for batch 441 = 0.6666666666666666 at d = 0.15152796855568895
# Max accuracy for batch 442 = 0.7916666666666667 at d = 0.0994336309917272
# Max accuracy for batch 443 = 0.8 at d = 0.060805898562073746
# Max accuracy for batch 444 = 0.8333333333333333 at d = 0.05255380684137345
# Max accuracy for batch 445 = 0.75 at d = 0.060106140360236204
# Max accuracy for batch 446 = 0.625 at d = 0.025859409943223
# Max accuracy for batch 447 = 0.7 at d = 0.1536789331436158
# Max accuracy for batch 448 = 0.7 at d = 0.09825927345454699
# Max accuracy for batch 449 = 0.875 at d = 0.059691474683582824
# Max accuracy for batch 450 = 0.75 at d = 0.08635267058014873
# Max accuracy for batch 451 = 0.7142857142857143 at d = 0.16733109676837932
# Max accuracy for batch 452 = 0.8333333333333333 at d = 0.14153325381875048
# Max accuracy for batch 453 = 1.0 at d = 0.09653506582975391
# Max accuracy for batch 454 = 0.9 at d = 0.11513643912971028
# Max accuracy for batch 455 = 0.7142857142857143 at d = 0.12533898073434835
# Max accuracy for batch 456 = 0.7857142857142857 at d = 0.07976870602369313
# Max accuracy for batch 457 = 0.75 at d = 0.023597491905093193
# Max accuracy for batch 458 = 0.6666666666666666 at d = 0.040891677141189575
# Max accuracy for batch 459 = 0.9285714285714286 at d = 0.12935924330353743
# Max accuracy for batch 460 = 0.9 at d = 0.08697530147433286
# Max accuracy for batch 461 = 0.7083333333333333 at d = 0.12379963475465783
# Max accuracy for batch 462 = 0.7 at d = 0.18171707755327238
# Max accuracy for batch 463 = 0.625 at d = 0.09641177576780324
# Max accuracy for batch 464 = 0.75 at d = 0.06380001592636109
# Max accuracy for batch 465 = 0.8333333333333333 at d = 0.07775774073600772
# Max accuracy for batch 466 = 0.6875 at d = 0.23232892394065874
# Max accuracy for batch 467 = 1.0 at d = 0.12833183488249789
# Max accuracy for batch 468 = 0.8333333333333333 at d = 0.13388742807507525
# Max accuracy for batch 469 = 0.6666666666666666 at d = 0.02403227037191391
# Max accuracy for batch 470 = 0.8125 at d = 0.07780794708430772
# Max accuracy for batch 471 = 0.9166666666666667 at d = 0.15245676057040702
# Max accuracy for batch 472 = 0.8333333333333333 at d = 0.08806620129942899
# Max accuracy for batch 473 = 0.9 at d = 0.07969075453281405
# Max accuracy for batch 474 = 0.6 at d = 0.04479053616523743
# Max accuracy for batch 475 = 0.8333333333333333 at d = 0.17047692222893251
# Max accuracy for batch 476 = 0.7916666666666667 at d = 0.11034306422621021
# Max accuracy for batch 477 = 0.7916666666666667 at d = 0.12225225687026986
# Max accuracy for batch 478 = 0.6666666666666666 at d = 0.07952078422904019
# Max accuracy for batch 479 = 0.75 at d = 0.1893936345279218
# Max accuracy for batch 480 = 0.625 at d = 0.07737093338370327
# Max accuracy for batch 481 = 0.9166666666666667 at d = 0.1552662400752307
# Max accuracy for batch 482 = 1.0 at d = 0.15710744459927095
# Max accuracy for batch 483 = 0.9166666666666667 at d = 0.17951060536503805
# Max accuracy for batch 484 = 0.6875 at d = 0.18331389912962925
# Max accuracy for batch 485 = 0.7619047619047619 at d = 0.14857203489542015
# Max accuracy for batch 486 = 0.75 at d = 0.1397501997053624
# Max accuracy for batch 487 = 0.6666666666666666 at d = 0.1263588467240334
# Max accuracy for batch 488 = 0.6666666666666667 at d = 0.1401634878516198
# Max accuracy for batch 489 = 0.8571428571428572 at d = 0.11024037423729904
# Max accuracy for batch 490 = 0.875 at d = 0.04799593065679075
# Max accuracy for batch 491 = 0.8 at d = 0.0631505468040705
# Max accuracy for batch 492 = 0.7083333333333333 at d = 0.06501131370663643
# Max accuracy for batch 493 = 1.0 at d = 0.07290183097124103
# Max accuracy for batch 494 = 0.9285714285714286 at d = 0.0963869818747044
# Max accuracy for batch 495 = 0.6666666666666666 at d = 0.2554598688185217
# Max accuracy for batch 496 = 0.6428571428571428 at d = 0.08815826484560974
# Max accuracy for batch 497 = 0.9375 at d = 0.09833051338791854
# Max accuracy for batch 498 = 0.8 at d = 0.13111728438735015
# Max accuracy for batch 499 = 0.75 at d = 0.050878905102610616
# Max accuracy for batch 500 = 0.8 at d = 0.029126895487308513
# Max accuracy for batch 501 = 0.7916666666666667 at d = 0.12884970216453084
# Max accuracy for batch 502 = 0.8 at d = 0.09597597718238837
# Max accuracy for batch 503 = 0.7916666666666667 at d = 0.20956850048899667
# Max accuracy for batch 504 = 0.9166666666666667 at d = 0.08758480837941174
# Max accuracy for batch 505 = 0.6666666666666667 at d = 0.07271149313449865
# Max accuracy for batch 506 = 0.5714285714285714 at d = 0.021595211699604988
# Max accuracy for batch 507 = 0.75 at d = 0.19157104656100288
# Max accuracy for batch 508 = 0.625 at d = 0.051244924455881136
# Max accuracy for batch 509 = 0.6666666666666666 at d = 0.03808233514428139
# Max accuracy for batch 510 = 0.7 at d = 0.1504636798053981
# Max accuracy for batch 511 = 0.75 at d = 0.08155902603268628
# Max accuracy for batch 512 = 0.9285714285714286 at d = 0.10948465219140058
# Max accuracy for batch 513 = 0.875 at d = 0.04538275428116323
# Max accuracy for batch 514 = 1.0 at d = 0.1832793402820827
# Max accuracy for batch 515 = 0.8571428571428572 at d = 0.1361011081933976
# Max accuracy for batch 516 = 0.9 at d = 0.08556026041507725
# Max accuracy for batch 517 = 0.75 at d = 0.06986781221628191
# Max accuracy for batch 518 = 0.75 at d = 0.19531219904124753
# Max accuracy for batch 519 = 0.8571428571428572 at d = 0.08741387736797335
# Max accuracy for batch 520 = 0.9166666666666667 at d = 0.11571211344003685
# Max accuracy for batch 521 = 0.7916666666666667 at d = 0.14851648315787325
# Max accuracy for batch 522 = 0.8333333333333333 at d = 0.07164572465419772
# Max accuracy for batch 523 = 1.0 at d = 0.25616221353411694
# Max accuracy for batch 524 = 0.75 at d = 0.20147900280356423
# Max accuracy for batch 525 = 0.9 at d = 0.07234899455308919
# Max accuracy for batch 526 = 0.875 at d = 0.08575007605552676
# Max accuracy for batch 527 = 0.7 at d = 0.0775932065546513
# Max accuracy for batch 528 = 0.7 at d = 0.040995209157466905
# Max accuracy for batch 529 = 0.6666666666666666 at d = 0.05535894463956359
# Max accuracy for batch 530 = 0.8333333333333333 at d = 0.11728372439742096
# Max accuracy for batch 531 = 0.8571428571428572 at d = 0.11289468410611159
# Max accuracy for batch 532 = 0.7 at d = 0.1284063042402268
# Max accuracy for batch 533 = 0.9 at d = 0.20902257332205787
# Max accuracy for batch 534 = 1.0 at d = 0.061761358052492166
# Max accuracy for batch 535 = 0.7916666666666667 at d = 0.12958914758265028
# Max accuracy for batch 536 = 0.5833333333333333 at d = 0.15623330777883537
# Max accuracy for batch 537 = 0.625 at d = 0.22366386863589305
# Max accuracy for batch 538 = 1.0 at d = 0.19746881681680695
# Max accuracy for batch 539 = 0.6666666666666667 at d = 0.12102779421210297
# Max accuracy for batch 540 = 0.6 at d = 0.3795023930072787
# Max accuracy for batch 541 = 0.8 at d = 0.10058498144149786
# Max accuracy for batch 542 = 0.9 at d = 0.09011697766184812
# Max accuracy for batch 543 = 0.875 at d = 0.12352878484129914
# Max accuracy for batch 544 = 0.625 at d = 0.18694722416996967
# Max accuracy for batch 545 = 0.9285714285714286 at d = 0.1628524634242059
# Max accuracy for batch 546 = 0.7916666666666667 at d = 0.09493743559718137
# Max accuracy for batch 547 = 0.9 at d = 0.14127317503094683
# Max accuracy for batch 548 = 1.0 at d = 0.04598245397210121
# Max accuracy for batch 549 = 0.6666666666666667 at d = 0.1572267151772977
# Max accuracy for batch 550 = 0.8333333333333333 at d = 0.0771775213479996
# Max accuracy for batch 551 = 0.6666666666666666 at d = 0.1708482550382615
# Max accuracy for batch 552 = 0.8571428571428572 at d = 0.09842765915393836
# Max accuracy for batch 553 = 0.8333333333333333 at d = 0.08235625255107881
# Max accuracy for batch 554 = 0.875 at d = 0.07468915650248531
# Max accuracy for batch 555 = 0.625 at d = 0.05880040347576143
# Max accuracy for batch 556 = 0.75 at d = 0.07892285063862803
# Max accuracy for batch 557 = 1.0 at d = 0.06747593769431115
# Max accuracy for batch 558 = 0.7916666666666667 at d = 0.12157835644483572
# Max accuracy for batch 559 = 0.9166666666666667 at d = 0.11318773707747465
# Max accuracy for batch 560 = 0.7083333333333333 at d = 0.13498393899202354
# Max accuracy for batch 561 = 0.7916666666666667 at d = 0.11472650139033802
# Max accuracy for batch 562 = 0.7857142857142857 at d = 0.2569482889175416
# Max accuracy for batch 563 = 0.8 at d = 0.05622248697280885
# Max accuracy for batch 564 = 0.7857142857142857 at d = 0.1418603538721801
# Max accuracy for batch 565 = 0.6666666666666666 at d = 0.19265974095463767
# Max accuracy for batch 566 = 0.8333333333333333 at d = 0.15681366923451434
# Max accuracy for batch 567 = 0.875 at d = 0.18647369623184218
# Max accuracy for batch 568 = 0.7857142857142857 at d = 0.08362100401520733
# Max accuracy for batch 569 = 0.7 at d = 0.055365806341171275
# Max accuracy for batch 570 = 0.9 at d = 0.10282835838198667
# Max accuracy for batch 571 = 0.875 at d = 0.1372711529135705
# Max accuracy for batch 572 = 0.6666666666666666 at d = 0.20978139960765851
# Max accuracy for batch 573 = 1.0 at d = 0.07733266961574559
# Max accuracy for batch 574 = 0.7777777777777778 at d = 0.15744724172353752
# Max accuracy for batch 575 = 0.7 at d = 0.07988920995593074
# Max accuracy for batch 576 = 0.7083333333333333 at d = 0.18366921371221556
# Max accuracy for batch 577 = 1.0 at d = 0.06566930432617668
# Max accuracy for batch 578 = 0.5833333333333334 at d = 0.1415379550755025
# Max accuracy for batch 579 = 0.8333333333333333 at d = 0.10353754836320883
# Max accuracy for batch 580 = 0.9 at d = 0.11804119867086416
# Max accuracy for batch 581 = 0.9 at d = 0.1168425843715668
# Max accuracy for batch 582 = 0.75 at d = 0.17503247076272976
# Max accuracy for batch 583 = 0.6904761904761905 at d = 0.23254055565595644
# Max accuracy for batch 584 = 0.6666666666666667 at d = 0.08295431056618696
# Max accuracy for batch 585 = 0.9166666666666667 at d = 0.09135093361139301
# Max accuracy for batch 586 = 0.8125 at d = 0.16299755454063425
# Max accuracy for batch 587 = 0.7 at d = 0.07736636632680893
# Max accuracy for batch 588 = 0.7916666666666667 at d = 0.08565433752536777
# Max accuracy for batch 589 = 0.6 at d = 0.035177428275346756
# Max accuracy for batch 590 = 0.75 at d = 0.1336045204848052
# Max accuracy for batch 591 = 0.875 at d = 0.025473638057708747
# Max accuracy for batch 592 = 0.6 at d = 0.11676147106289869
# Max accuracy for batch 593 = 1.0 at d = 0.14855367366969596
# Max accuracy for batch 594 = 1.0 at d = 0.23894052343070527
# Max accuracy for batch 595 = 1.0 at d = 0.18087941426038756
# Max accuracy for batch 596 = 0.75 at d = 0.12172017085552223
# Max accuracy for batch 597 = 0.9166666666666667 at d = 0.11795232421159751
# Max accuracy for batch 598 = 0.7142857142857143 at d = 0.04487262623012067
# Max accuracy for batch 599 = 0.7916666666666667 at d = 0.10571155256032949
# Max accuracy for batch 600 = 0.7916666666666667 at d = 0.07565988378226762
# Max accuracy for batch 601 = 0.6190476190476191 at d = 0.08030967071652417
# Max accuracy for batch 602 = 0.9375 at d = 0.18673827336728588
# Max accuracy for batch 603 = 0.8 at d = 0.07263796225190167
# Max accuracy for batch 604 = 1.0 at d = 0.14954428593814384
# Max accuracy for batch 605 = 0.8 at d = 0.09316683551669125
# Max accuracy for batch 606 = 0.7 at d = 0.07887888723611836
# Max accuracy for batch 607 = 0.9 at d = 0.20088582208752648
# Max accuracy for batch 608 = 0.7 at d = 0.14169495809078225
# Max accuracy for batch 609 = 0.75 at d = 0.08853697368502622
# Max accuracy for batch 610 = 0.8333333333333333 at d = 0.08865402108430864
# Max accuracy for batch 611 = 0.875 at d = 0.1724770588576795
# Max accuracy for batch 612 = 0.6666666666666666 at d = 0.2696905099749567
# Max accuracy for batch 613 = 0.6666666666666666 at d = 0.03765205146372319
# Max accuracy for batch 614 = 0.6875 at d = 0.05684913629293442
# Max accuracy for batch 615 = 0.5833333333333333 at d = 0.1112305999398232
# Max accuracy for batch 616 = 0.8333333333333333 at d = 0.08629105779528623
# Max accuracy for batch 617 = 0.6666666666666666 at d = 0.06853763255476952
# Max accuracy for batch 618 = 0.625 at d = 0.08318463933467868
# Max accuracy for batch 619 = 0.7857142857142857 at d = 0.06974128487706188
# Max accuracy for batch 620 = 1.0 at d = 0.06858111700415614
# Max accuracy for batch 621 = 0.7916666666666667 at d = 0.08846711665391926
# Max accuracy for batch 622 = 0.625 at d = 0.07667273283004761
# Max accuracy for batch 623 = 0.7 at d = 0.02658364281058312
# Max accuracy for batch 624 = 0.875 at d = 0.10680396419763571
# Max accuracy for batch 625 = 1.0 at d = 0.04589004892110826
# Max accuracy for batch 626 = 0.7 at d = 0.1258831478655339
# Max accuracy for batch 627 = 0.625 at d = 0.05450112745165825
# Max accuracy for batch 628 = 0.8571428571428572 at d = 0.09031612247228626
# Max accuracy for batch 629 = 0.6666666666666666 at d = 0.26913970291614553
# Max accuracy for batch 630 = 0.6666666666666666 at d = 0.27843237926065945
# Max accuracy for batch 631 = 0.75 at d = 0.023204119220376018
# Max accuracy for batch 632 = 0.8 at d = 0.11541490167379387
# Max accuracy for batch 633 = 0.6666666666666667 at d = 0.23274647852778452
# Max accuracy for batch 634 = 0.75 at d = 0.0649793940931559
# Max accuracy for batch 635 = 0.7 at d = 0.07462590375542644
# Max accuracy for batch 636 = 0.7619047619047619 at d = 0.06372427196800712
# Max accuracy for batch 637 = 0.6666666666666667 at d = 0.09167834186553958
# Max accuracy for batch 638 = 0.8125 at d = 0.08327187079191212
# Max accuracy for batch 639 = 0.7619047619047619 at d = 0.10216021555662158
# Max accuracy for batch 640 = 0.7083333333333333 at d = 0.08777670893073086
# Max accuracy for batch 641 = 1.0 at d = 0.10878808611631396
# Max accuracy for batch 642 = 0.6428571428571428 at d = 0.04798940433561805
# Max accuracy for batch 643 = 0.9285714285714286 at d = 0.11156270611286168
# Max accuracy for batch 644 = 0.7916666666666667 at d = 0.10708907419443137
# Max accuracy for batch 645 = 0.7 at d = 0.07141567807644611
# Max accuracy for batch 646 = 0.7 at d = 0.2363247174322607
# Max accuracy for batch 647 = 0.5952380952380952 at d = 0.07197188735008242
# Max accuracy for batch 648 = 0.6000000000000001 at d = 0.1609755826592446
# Max accuracy for batch 649 = 0.6666666666666667 at d = 0.19388244429230705
# Max accuracy for batch 650 = 0.8333333333333333 at d = 0.16501131370663644
# Max accuracy for batch 651 = 0.6 at d = 0.041410334408283234
# Max accuracy for batch 652 = 0.6666666666666666 at d = 0.015302506275475025
# Max accuracy for batch 653 = 0.8 at d = 0.2191217427849771
# Max accuracy for batch 654 = 0.7083333333333333 at d = 0.16638969220221056
# Max accuracy for batch 655 = 0.6666666666666666 at d = 0.25685469037294406
# Max accuracy for batch 656 = 0.7142857142857143 at d = 0.19157711061835303
# Max accuracy for batch 657 = 0.7083333333333333 at d = 0.11510787019133573
# Max accuracy for batch 658 = 0.8 at d = 0.09796721108257778
# Max accuracy for batch 659 = 0.7 at d = 0.1457653683871032
# Max accuracy for batch 660 = 0.7 at d = 0.049712843209505087
# Max accuracy for batch 661 = 0.8 at d = 0.08542362016439442
# Max accuracy for batch 662 = 0.9166666666666667 at d = 0.0920919589400292
# Max accuracy for batch 663 = 0.9 at d = 0.08788740111887461
# Max accuracy for batch 664 = 0.6666666666666666 at d = 0.1778070147037507
# Max accuracy for batch 665 = 0.7916666666666667 at d = 0.0886730495989323
# Max accuracy for batch 666 = 0.7083333333333333 at d = 0.11704798632860192
# Max accuracy for batch 667 = 0.8 at d = 0.07009442700445656
# Max accuracy for batch 668 = 0.9166666666666667 at d = 0.1011666214317084
# Max accuracy for batch 669 = 1.0 at d = 0.14969582366943368
# Max accuracy for batch 670 = 0.7857142857142857 at d = 0.1767722873389722
# Max accuracy for batch 671 = 0.8 at d = 0.08953217616677289
# Max accuracy for batch 672 = 1.0 at d = 0.08446536144614225
# Max accuracy for batch 673 = 0.8 at d = 0.08017730994522576
# Max accuracy for batch 674 = 0.8125 at d = 0.06806227298080925
# Max accuracy for batch 675 = 0.75 at d = 0.15743303823471078
# Max accuracy for batch 676 = 0.6666666666666666 at d = 0.05162980507314208
# Max accuracy for batch 677 = 0.8 at d = 0.17280200064182294
# Max accuracy for batch 678 = 0.625 at d = 0.1385898105502129
# Max accuracy for batch 679 = 0.8 at d = 0.08005521705746654
# Max accuracy for batch 680 = 0.75 at d = 0.07920439937710766
# Max accuracy for batch 681 = 0.9166666666666667 at d = 0.07276164731383328
# Max accuracy for batch 682 = 0.75 at d = 0.2619805189073088
# Max accuracy for batch 683 = 0.875 at d = 0.1114686009585858
# Max accuracy for batch 684 = 0.6666666666666666 at d = 0.06682923322916035
# Max accuracy for batch 685 = 0.625 at d = 0.024868184700608253
# Max accuracy for batch 686 = 0.6428571428571428 at d = 0.039164635524153724
# Max accuracy for batch 687 = 0.8 at d = 0.06946590122580532
# Max accuracy for batch 688 = 0.7916666666666667 at d = 0.11486346864700325
# Max accuracy for batch 689 = 0.7916666666666667 at d = 0.08427462920546536
# Max accuracy for batch 690 = 0.7857142857142857 at d = 0.06041504526138308
# Max accuracy for batch 691 = 0.75 at d = 0.03006897094845773
# Max accuracy for batch 692 = 0.7916666666666667 at d = 0.08114892800152307
# Max accuracy for batch 693 = 0.875 at d = 0.06135221609473229
# Max accuracy for batch 694 = 0.7619047619047619 at d = 0.10719763551652439
# Max accuracy for batch 695 = 0.875 at d = 0.07997406660020356
# Max accuracy for batch 696 = 0.6 at d = 0.07247462123632431
# Max accuracy for batch 697 = 1.0 at d = 0.1254098182916642
# Max accuracy for batch 698 = 0.6904761904761905 at d = 0.10806007505953319
# Max accuracy for batch 699 = 0.5714285714285714 at d = 0.23280104690790193
# Max accuracy for batch 700 = 1.0 at d = 0.08905371060967449
# Max accuracy for batch 701 = 0.6666666666666666 at d = 0.058291643202304844
# Max accuracy for batch 702 = 0.9285714285714286 at d = 0.07418775703012948
# Max accuracy for batch 703 = 0.6000000000000001 at d = 0.1749916639328004
# Max accuracy for batch 704 = 0.7857142857142857 at d = 0.20538149762153635
# Max accuracy for batch 705 = 0.7857142857142857 at d = 0.05543332701921466
# Max accuracy for batch 706 = 1.0 at d = 0.045732391566038144
# Max accuracy for batch 707 = 0.7916666666666667 at d = 0.11524283380806455
# Max accuracy for batch 708 = 0.75 at d = 0.07444313384592538
# Max accuracy for batch 709 = 0.9166666666666667 at d = 0.10009802125394351
# Max accuracy for batch 710 = 0.5833333333333334 at d = 0.031826745718717575
# Max accuracy for batch 711 = 0.6666666666666666 at d = 0.040214940905570984
# Max accuracy for batch 712 = 1.0 at d = 0.08284067019820218
# Max accuracy for batch 713 = 0.7083333333333333 at d = 0.137941127717495
# ...
# Max accuracy for batch 936 = 0.9166666666666667 at d = 0.09793653819710024
# Max accuracy for batch 937 = 1.0 at d = 0.1778341578245164
# Max accuracy for batch 938 = 0.5416666666666666 at d = 0.12984628593921665
# Max accuracy for batch 939 = 0.6666666666666666 at d = 0.03652484342455864
# Max accuracy for batch 940 = 0.875 at d = 0.12430665460228929
# Max accuracy for batch 941 = 0.5833333333333334 at d = 0.21427685073018088
# Max accuracy for batch 942 = 0.875 at d = 0.1930823449492456
# Max accuracy for batch 943 = 1.0 at d = 0.11536147108674055
# Max accuracy for batch 944 = 0.6666666666666666 at d = 0.1938540691137315
# Max accuracy for batch 945 = 0.8333333333333333 at d = 0.17239224845170986
# Max accuracy for batch 946 = 0.8333333333333333 at d = 0.05308949723839762
# Max accuracy for batch 947 = 0.8 at d = 0.11618908590078358
# Max accuracy for batch 948 = 0.75 at d = 0.03878680661320688
# Max accuracy for batch 949 = 0.5833333333333334 at d = 0.040076106786727905
# Max accuracy for batch 950 = 0.8333333333333333 at d = 0.24208249372243895
# Max accuracy for batch 951 = 0.9166666666666667 at d = 0.09691977360844617
# Max accuracy for batch 952 = 0.8 at d = 0.04978403729200365
# Max accuracy for batch 953 = 0.7916666666666667 at d = 0.19996999692916884
# Max accuracy for batch 954 = 0.7619047619047619 at d = 0.1510940114557744
# Max accuracy for batch 955 = 0.75 at d = 0.28070047700405143
# Max accuracy for batch 956 = 0.75 at d = 0.06930554801225663
# Max accuracy for batch 957 = 0.9166666666666667 at d = 0.12061904489994058
# Max accuracy for batch 958 = 0.75 at d = 0.11003091931343079
# Max accuracy for batch 959 = 0.6666666666666666 at d = 0.24466227561235443
# Max accuracy for batch 960 = 0.7 at d = 0.25683622105419657
# Max accuracy for batch 961 = 0.7916666666666667 at d = 0.11250168702006347
# Max accuracy for batch 962 = 0.75 at d = 0.06183687347173694
# Max accuracy for batch 963 = 1.0 at d = 0.12980978825688372
# Max accuracy for batch 964 = 0.8 at d = 0.1766855370402337
# Max accuracy for batch 965 = 1.0 at d = 0.11027057301998144
# Max accuracy for batch 966 = 0.8 at d = 0.04182918813824654
# Max accuracy for batch 967 = 0.75 at d = 0.10688250559568413
# Max accuracy for batch 968 = 0.75 at d = 0.11739489199221143
# Max accuracy for batch 969 = 0.6666666666666666 at d = 0.03340684387087822
# Max accuracy for batch 970 = 0.7857142857142857 at d = 0.08589635720849043
# Max accuracy for batch 971 = 0.9 at d = 0.07336041410267358
# Max accuracy for batch 972 = 0.9166666666666667 at d = 0.08006812040880329
# Max accuracy for batch 973 = 0.8 at d = 0.09205710276961332
# Max accuracy for batch 974 = 0.75 at d = 0.08826136305928234
# Max accuracy for batch 975 = 0.9285714285714286 at d = 0.07145517063140872
# Max accuracy for batch 976 = 0.8 at d = 0.05045637401938441
# Max accuracy for batch 977 = 0.6428571428571428 at d = 0.13665602031350144
# Max accuracy for batch 978 = 0.5 at d = 0.32952381199598335
# Max accuracy for batch 979 = 0.8333333333333333 at d = 0.174716121017933
# Max accuracy for batch 980 = 0.7083333333333333 at d = 0.2462162822932007
# Max accuracy for batch 981 = 0.7619047619047619 at d = 0.06288892710208893
# Max accuracy for batch 982 = 0.8333333333333333 at d = 0.15889220792055136
# Max accuracy for batch 983 = 0.7857142857142857 at d = 0.1519000228643418
# Max accuracy for batch 984 = 0.6666666666666666 at d = 0.0455227792263031
# Max accuracy for batch 985 = 0.8 at d = 0.07629399758577349
# Max accuracy for batch 986 = 0.5416666666666666 at d = 0.18327213549613963
# Max accuracy for batch 987 = 0.8 at d = 0.08843852072954184
# Max accuracy for batch 988 = 0.8 at d = 0.07614903920888905
# Max accuracy for batch 989 = 0.7857142857142857 at d = 0.12134166811406621
# Max accuracy for batch 990 = 0.6666666666666667 at d = 0.1481194617152215
# Max accuracy for batch 991 = 0.9375 at d = 0.06269694980978968
# Max accuracy for batch 992 = 0.8333333333333333 at d = 0.2946630940437319
# Max accuracy for batch 993 = 0.6666666666666666 at d = 0.03666008625924588
# Max accuracy for batch 994 = 0.75 at d = 0.05528367328643802
# Max accuracy for batch 995 = 0.75 at d = 0.15534807878732693
# Max accuracy for batch 996 = 0.875 at d = 0.1176003783345223
# Max accuracy for batch 997 = 0.8 at d = 0.1462559298425914
# Max accuracy for batch 998 = 0.9 at d = 0.0997134095728398
# Max accuracy for batch 999 = 0.7 at d = 0.10185676509141928
# Max accuracy for batch 1000 = 0.7 at d = 0.07710867419838907
# Max accuracy for batch 1001 = 0.8333333333333333 at d = 0.04789997407794
# Max accuracy for batch 1002 = 0.5833333333333334 at d = 0.2193250910043718
# Max accuracy for batch 1003 = 0.75 at d = 0.06100558233261111
# Max accuracy for batch 1004 = 0.875 at d = 0.08745193062722689
# Max accuracy for batch 1005 = 0.8571428571428572 at d = 0.09732098063826566
# Max accuracy for batch 1006 = 0.7916666666666667 at d = 0.15831650140881548
# Max accuracy for batch 1007 = 0.7 at d = 0.04564351737499239
# Max accuracy for batch 1008 = 0.75 at d = 0.0817609511613846
# Max accuracy for batch 1009 = 0.8 at d = 0.06715893521904948
# Max accuracy for batch 1010 = 0.6190476190476191 at d = 0.10112427583336836
# Max accuracy for batch 1011 = 0.8 at d = 0.06078596594929697
# Max accuracy for batch 1012 = 0.625 at d = 0.025506872683763504
# Max accuracy for batch 1013 = 0.8333333333333333 at d = 0.10242661601305014
# Max accuracy for batch 1014 = 0.875 at d = 0.0797767205536366
# Max accuracy for batch 1015 = 0.6666666666666667 at d = 0.08536850553750996
# Max accuracy for batch 1016 = 0.9 at d = 0.10509090363979345
# Max accuracy for batch 1017 = 0.75 at d = 0.049906378895044345
# Max accuracy for batch 1018 = 0.8 at d = 0.16165926399827013
# Max accuracy for batch 1019 = 0.6875 at d = 0.05028180751204492
# Max accuracy for batch 1020 = 0.75 at d = 0.019176963716745377
# Max accuracy for batch 1021 = 0.6875 at d = 0.21064897009730355
# Max accuracy for batch 1022 = 0.75 at d = 0.06770195692777636
# Max accuracy for batch 1023 = 0.8333333333333333 at d = 0.09403595554828648
# Max accuracy for batch 1024 = 0.9166666666666667 at d = 0.1323050085157157
# Max accuracy for batch 1025 = 0.9 at d = 0.07432123094797138
# Max accuracy for batch 1026 = 0.8 at d = 0.05910253235697749
# Max accuracy for batch 1027 = 0.6666666666666667 at d = 0.13877207872271546
# Max accuracy for batch 1028 = 0.9285714285714286 at d = 0.1144500904381276
# Max accuracy for batch 1029 = 0.75 at d = 0.05267256379127505
# Max accuracy for batch 1030 = 0.7 at d = 0.0672711122632027
# Max accuracy for batch 1031 = 0.9285714285714286 at d = 0.08001998135447508
# Max accuracy for batch 1032 = 1.0 at d = 0.3155428012311461
# Max accuracy for batch 1033 = 0.8888888888888888 at d = 0.13038049966096887
# Max accuracy for batch 1034 = 0.75 at d = 0.18965631133317962
# Max accuracy for batch 1035 = 0.9444444444444444 at d = 0.05989265727996829
# Max accuracy for batch 1036 = 0.8571428571428572 at d = 0.11605813369154938
# Max accuracy for batch 1037 = 0.5 at d = 0.07404356122016909
# Max accuracy for batch 1038 = 0.8 at d = 0.1168570783436299
# Max accuracy for batch 1039 = 0.75 at d = 0.09803457641601565
# Max accuracy for batch 1040 = 1.0 at d = 0.18302220752835285
# Max accuracy for batch 1041 = 0.6666666666666666 at d = 0.28355300930142424
# Max accuracy for batch 1042 = 0.6666666666666666 at d = 0.0493153719455004
# Max accuracy for batch 1043 = 0.625 at d = 0.08639907959103588
# Max accuracy for batch 1044 = 0.9285714285714286 at d = 0.12294905248284349
# Max accuracy for batch 1045 = 0.9166666666666667 at d = 0.13451180419325837
# Max accuracy for batch 1046 = 0.7 at d = 0.10370674610137942
# Max accuracy for batch 1047 = 0.6000000000000001 at d = 0.1257309762239457
# Max accuracy for batch 1048 = 0.5 at d = 0.22425612124800698
# Max accuracy for batch 1049 = 0.8333333333333333 at d = 0.031005129441618928
# Max accuracy for batch 1050 = 0.8571428571428572 at d = 0.09824605840444567
# Max accuracy for batch 1051 = 0.9 at d = 0.10930679494142537
# Max accuracy for batch 1052 = 0.7 at d = 0.07039336434006693
# Max accuracy for batch 1053 = 0.9375 at d = 0.17301683358848108
# Max accuracy for batch 1054 = 0.8571428571428572 at d = 0.07023200838267807
# Max accuracy for batch 1055 = 0.7142857142857143 at d = 0.2646119416952135
# Max accuracy for batch 1056 = 0.75 at d = 0.038493466079235095
# Max accuracy for batch 1057 = 0.6666666666666666 at d = 0.06531771038472656
# Max accuracy for batch 1058 = 0.8333333333333333 at d = 0.1627940190434457
# Max accuracy for batch 1059 = 0.9375 at d = 0.07444609314203265
# Max accuracy for batch 1060 = 0.75 at d = 0.14016295781731614
# Max accuracy for batch 1061 = 0.9 at d = 0.10111107018589974
# Max accuracy for batch 1062 = 0.8 at d = 0.09221147358417514
# Max accuracy for batch 1063 = 0.8571428571428572 at d = 0.14570717737078676
# Max accuracy for batch 1064 = 0.8 at d = 0.04683765561878683
# Max accuracy for batch 1065 = 0.7857142857142857 at d = 0.14980497872829446
# Max accuracy for batch 1066 = 0.7857142857142857 at d = 0.2002121769636871
# Max accuracy for batch 1067 = 0.7 at d = 0.1442962321639062
# Max accuracy for batch 1068 = 0.9285714285714286 at d = 0.14246657912433158
# Max accuracy for batch 1069 = 0.9375 at d = 0.18768927186727535
# Max accuracy for batch 1070 = 0.7 at d = 0.1029344055652619
# Max accuracy for batch 1071 = 0.75 at d = 0.18224892947077764
# Max accuracy for batch 1072 = 0.5833333333333334 at d = 0.03207433596253395
# Max accuracy for batch 1073 = 0.9 at d = 0.1985200855284931
# Max accuracy for batch 1074 = 0.7 at d = 0.07808866512775425
# Max accuracy for batch 1075 = 0.6666666666666667 at d = 0.17585443750023855
# Max accuracy for batch 1076 = 0.6666666666666667 at d = 0.1297699311971665
# Max accuracy for batch 1077 = 0.6666666666666666 at d = 0.14901131370663642
# Max accuracy for batch 1078 = 0.8333333333333333 at d = 0.041576445549726504
# Max accuracy for batch 1079 = 0.8571428571428572 at d = 0.09905094781517987
# Max accuracy for batch 1080 = 0.8 at d = 0.05952878484129909
# Max accuracy for batch 1081 = 0.6666666666666666 at d = 0.02863863669335842
# Max accuracy for batch 1082 = 0.875 at d = 0.11271753570437437
# Max accuracy for batch 1083 = 0.75 at d = 0.10309859859943393
# Max accuracy for batch 1084 = 0.7857142857142857 at d = 0.09433242736756808
# Max accuracy for batch 1085 = 0.7083333333333333 at d = 0.1619811744391919
# Max accuracy for batch 1086 = 0.8333333333333333 at d = 0.21569086904823798
# Max accuracy for batch 1087 = 0.7 at d = 0.06011835262179377
# Max accuracy for batch 1088 = 0.75 at d = 0.046441259965300574
# Max accuracy for batch 1089 = 0.7857142857142857 at d = 0.19589473640918742
# Max accuracy for batch 1090 = 0.8 at d = 0.09609424757957463
# Max accuracy for batch 1091 = 0.8 at d = 0.16282600153982651
# Max accuracy for batch 1092 = 0.6428571428571428 at d = 0.0500021146386862
# Max accuracy for batch 1093 = 1.0 at d = 0.09784568466246135
# Max accuracy for batch 1094 = 0.8333333333333333 at d = 0.12272296267747884
# Max accuracy for batch 1095 = 0.75 at d = 0.14544487830996522
# Max accuracy for batch 1096 = 0.8333333333333333 at d = 0.039522583767771735
# Max accuracy for batch 1097 = 1.0 at d = 0.1501214710175992
# Max accuracy for batch 1098 = 0.7916666666666667 at d = 0.060849279835820225
# Max accuracy for batch 1099 = 0.8333333333333333 at d = 0.10123293127119548
# Max accuracy for batch 1100 = 0.7083333333333333 at d = 0.09835067272186282
# Max accuracy for batch 1101 = 1.0 at d = 0.13428797078132637
# Max accuracy for batch 1102 = 1.0 at d = 0.10943398189544684
# Max accuracy for batch 1103 = 0.5 at d = 0.28069910296797773
# Max accuracy for batch 1104 = 0.625 at d = 0.07596645280718806
# Max accuracy for batch 1105 = 0.6875 at d = 0.1667210204899312
# Max accuracy for batch 1106 = 0.7857142857142857 at d = 0.07617116196453577
# Max accuracy for batch 1107 = 0.9375 at d = 0.14074768924713144
# Max accuracy for batch 1108 = 0.8333333333333333 at d = 0.05396739843487741
# Max accuracy for batch 1109 = 0.9375 at d = 0.11368933269381531
# Max accuracy for batch 1110 = 0.875 at d = 0.10662928758561618
# Max accuracy for batch 1111 = 0.7916666666666667 at d = 0.10330281782150275
# Max accuracy for batch 1112 = 1.0 at d = 0.1613725981563331
# Max accuracy for batch 1113 = 0.9 at d = 0.1369041856229306
# Max accuracy for batch 1114 = 0.75 at d = 0.09743847152590757
# Max accuracy for batch 1115 = 0.6666666666666666 at d = 0.05230605065822602
# Max accuracy for batch 1116 = 1.0 at d = 0.05686687980592253
# Max accuracy for batch 1117 = 0.8571428571428572 at d = 0.14016790571808824
# Max accuracy for batch 1118 = 0.6 at d = 0.12834898462891586
# Max accuracy for batch 1119 = 1.0 at d = 0.09096182748675352
# Max accuracy for batch 1120 = 0.6875 at d = 0.24855999612808244
# Max accuracy for batch 1121 = 0.6428571428571428 at d = 0.2104906289875509
# Max accuracy for batch 1122 = 0.7857142857142857 at d = 0.18787536010146155
# Max accuracy for batch 1123 = 0.75 at d = 0.16099214816093455
# Max accuracy for batch 1124 = 0.6666666666666666 at d = 0.1874926744401456
# Max accuracy for batch 1125 = 0.6666666666666666 at d = 0.09188718688488007
# Max accuracy for batch 1126 = 0.6666666666666666 at d = 0.05929029366374017
# Max accuracy for batch 1127 = 0.75 at d = 0.07846554650366311
# Max accuracy for batch 1128 = 1.0 at d = 0.08749174565076834
# Max accuracy for batch 1129 = 0.7916666666666667 at d = 0.07577759423851971
# Max accuracy for batch 1130 = 0.8333333333333333 at d = 0.16125556683540354
# Max accuracy for batch 1131 = 0.7142857142857143 at d = 0.17220393425226221
# Max accuracy for batch 1132 = 0.9166666666666667 at d = 0.11962641450762757
# Max accuracy for batch 1133 = 0.7857142857142857 at d = 0.0623752635419369
# Max accuracy for batch 1134 = 0.7 at d = 0.04851880472898484
# Max accuracy for batch 1135 = 0.6428571428571428 at d = 0.07542427274584773
# Max accuracy for batch 1136 = 0.75 at d = 0.10302276167273527
# Max accuracy for batch 1137 = 0.625 at d = 0.08527401834726334
# Max accuracy for batch 1138 = 0.7083333333333333 at d = 0.08398871082067494
# Max accuracy for batch 1139 = 0.5555555555555556 at d = 0.25093322318792355
# Max accuracy for batch 1140 = 0.7916666666666667 at d = 0.08085085514187818
# Max accuracy for batch 1141 = 0.7142857142857143 at d = 0.25565516717731973
# Max accuracy for batch 1142 = 0.9375 at d = 0.1500260219126941
# Max accuracy for batch 1143 = 0.7857142857142857 at d = 0.11665676745772369
# Max accuracy for batch 1144 = 0.8333333333333333 at d = 0.06882506988942627
# Max accuracy for batch 1145 = 0.9444444444444444 at d = 0.06199657183885576
# Max accuracy for batch 1146 = 0.9285714285714286 at d = 0.1065549843013287
# Max accuracy for batch 1147 = 0.7857142857142857 at d = 0.06555083614587787
# Max accuracy for batch 1148 = 0.5714285714285714 at d = 0.04893685504794121
# Max accuracy for batch 1149 = 0.8333333333333333 at d = 0.1638961932361127
# Max accuracy for batch 1150 = 0.9166666666666667 at d = 0.2030478616356851
# Max accuracy for batch 1151 = 0.8 at d = 0.12416612032055863
# Max accuracy for batch 1152 = 0.6875 at d = 0.0712221703231335
# Max accuracy for batch 1153 = 0.8333333333333333 at d = 0.07795691037178043
# Max accuracy for batch 1154 = 1.0 at d = 0.15949182656407368
# Max accuracy for batch 1155 = 0.7083333333333333 at d = 0.11767325899004943
# Max accuracy for batch 1156 = 0.7 at d = 0.05068034717440606
# Max accuracy for batch 1157 = 0.6666666666666666 at d = 0.021939916208386423
# Max accuracy for batch 1158 = 0.8333333333333333 at d = 0.11667491981387146
# Max accuracy for batch 1159 = 0.75 at d = 0.0376460999250412
# Max accuracy for batch 1160 = 0.9 at d = 0.12433958502113829
# Max accuracy for batch 1161 = 0.9166666666666667 at d = 0.10596561571955687
# Max accuracy for batch 1162 = 0.6666666666666666 at d = 0.04495210573077202
# Max accuracy for batch 1163 = 0.9285714285714286 at d = 0.07495063466951252
# Max accuracy for batch 1164 = 0.875 at d = 0.12607008981704715
# Max accuracy for batch 1165 = 0.8333333333333333 at d = 0.11660960057377823
# Max accuracy for batch 1166 = 0.75 at d = 0.05201131370663643
# Max accuracy for batch 1167 = 0.7083333333333333 at d = 0.13715193122625358
# Max accuracy for batch 1168 = 1.0 at d = 0.14720159769058228
# Avg acc across all batches=0.7752673224978611 at d=0.11352895596805959
